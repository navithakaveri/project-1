# %%
from googleapiclient.discovery import build
import pymongo
import mysql.connector
import pymysql
import pandas as pd
import streamlit as st

# %%
def api_connect():#API connect
    #api_id="#AIzaSyBl0E4kWiD-oXL6fSrJtuu3cAFV1PJ6KuY"
    api_id="AIzaSyBX1ptO4VmjXOzb-zzohxQInRYfzrY2-xU"
    api_service_name="youtube"
    api_version="v3"
    youtube=build(api_service_name,api_version,developerKey=api_id)
    return youtube
youtube=api_connect()

# %%
#GETTING CHANNEL INFORMATION
def get_channel_info(channel_id):
  
   request = youtube.channels().list(
      part="snippet,contentDetails,statistics",
      id=channel_id
   )
   response = request.execute()
   for i in response['items']:
      data=dict(Channel_Name=i["snippet"]["title"],
                  Channel_Id=i["id"],
                  Subscribers=i["statistics"]["subscriberCount"],
                  Views=i["statistics"]["viewCount"],
                  Total_Videos=i['statistics']['videoCount'],
                  Channel_Description=i["snippet"]["description"],
                  Playlist_Id=i["contentDetails"]["relatedPlaylists"]["uploads"])

   return data

# %%
channel_detail= get_channel_info("UCeQnqwVSQM8W0o1E5nWql2g")
channel_detail
# Out:
# {'Channel_Name': 'Colour of Dreams',
#  'Channel_Id': 'UCeQnqwVSQM8W0o1E5nWql2g',
#  'Subscribers': '431000',
#  'Views': '120558517',
#  'Total_Videos': '476',
#  'Channel_Description': 'Hii Friends,I am Suman (creator of Colour of Dreams)........ \n\nThis is a Mehndi Art channel.Here, You can learn many many new mehndi designs..These Mehndi Design Tutorials will add value in your practice also.....And If you like my work then please Subscribe to my channel & hit the bell icon there...\n\n\nArt is longing. You never arrive, but you keep going in the hope that you will.\n―  Anselm Kiefer\n\n\nEmail:- shrishreya056@gmail.com \n\n\n',
#  'Playlist_Id': 'UUeQnqwVSQM8W0o1E5nWql2g'}

# %%
#GETTING VIDEO'S ID
def get_video_ids(channel_id):
    video_ids=[]
    response=youtube.channels().list(id=channel_id,
                                     part='contentDetails').execute()
                                     
    playlist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    next_page_token = None
    
    while True:
        response1 =youtube.playlistItems().list(
                                            part='snippet',
                                            playlistId=playlist_Id,
                                            maxResults=50,
                                            pageToken=next_page_token).execute()
        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token=response1.get("nextPageToken")
        
        if next_page_token is None:
            break
    return video_ids

# %%
video_Ids=get_video_ids("UCeQnqwVSQM8W0o1E5nWql2g")
video_Ids
# Out:
# ['tUBnJODVsEg',
#  'genjlybIbTs',
#  'mlwvUOvls7E',
#  'V19X90vZT_w',
#  'szlFqwBYPeQ',
#  '4TYZx5midWQ',
#  'Ffd5STYuN20',
#  'Wcy4SZU3nOE',
#  'gfel3Ij9yrI',
#  '68qJ9KFgigE',
#  '3yC1QSkJgl4',
#  '2FjTLgAXAXA',
#  'Ous2DXxlDPs',
#  'Qrcpr4aT8jQ',
#  'hzIT14yAau4',
#  'Ro_7-a3tGeg',
#  'l7myt96UR7w',
#  'qeVvVoird_c',
#  '0Yx-5dyWqE8',
#  'oLFo01E1fw0',
#  'sGGGVAo_wGo',
#  'mg-C0L1X_IY',
#  'AyKiyW2bMnU',
#  'Yse-0YVOc3o',
#  'z1jfHr58VpE',
#  'WWsNA0xKK9w',
#  'rAFgtgbw710',
#  'jo6Dt4R8dmU',
#  'ZC2-olAtgrM',
#  'hPmOyWgae8I',
#  'xKy5ZLO2_rs',
#  'YaFe2dlHoQc',
#  'JIIXJdEzQp8',
#  'X2YGpikKF3o',
#  'Qn_X_0deQoM',
#  'k2FIzUXflRI',
#  '3caaqu9hH48',
#  'F_stDXo6q_A',
#  'pq8V8DrN00E',
#  'U8Utb69YxqU',
#  'y1y8LlJHRiw',
#  '93YAE0dKnqo',
#  'suI1ysJRMFg',
#  'vWy7m02yPHQ',
#  'zmI3alwB_p4',
#  'bYm3XedadHw',
#  'Mjz046oRClg',
#  'R2uPcXYWHkw',
#  'B1ebUIMD5vY',
#  'TeGJighTm9E',
#  'df7rCAgtazg',
#  'AJOW7XjM-fE',
#  'hKMK8CgOoK4',
#  'j9cX8XCBoAM',
#  'vTf9oeHQNRQ',
#  'fb2K5x1yiX8',
#  'yO6UKnqgyfU',
#  'uiSn6iW_IMc',
#  'TOffBUlhOGA',
#  'Z5G9k58Go5o',
#  '3F4TYhdrk28',
#  'pAjFV5yBZRk',
#  'BZYI1PJzjZ0',
#  'TNgRQaPx0co',
#  'o1FY94cczE4',
#  'lWMYwWLsO8A',
#  'O3VV4XpgemI',
#  'Dy8UYdD2lmE',
#  'iehGP44hg-I',
#  'L2Eb3bdKJhw',
#  'VH9DjUBqzkk',
#  '9jO9gYbq4wM',
#  'kIivAlTKlaY',
#  '1esUzWzs2qY',
#  'rck1fgl8530',
#  'PIIUOrgHDx0',
#  '4F_u89fIs3s',
#  'lnuF_i_w1Vs',
#  'sV0mkSBaykY',
#  'TcTDNDJSoEA',
#  'Dx-GRG1XDQ8',
#  'lEvcbWmwviM',
#  '5kLN7uEPAFI',
#  'kZ8TWbkMYsw',
#  'S46oH3Q7z4o',
#  'UlG7EyFUQXg',
#  'Mts_in7jiF4',
#  '8B5BBGN15Nw',
#  'GckxyFZQ6JI',
#  'ojm9Q3-vKiM',
#  '9sCQn-S-uYs',
#  'rjLmLCGVl2A',
#  'RQX7hvWjbxQ',
#  'kvk0K6UtcTc',
#  'A0aESfUlF3M',
#  'QAkgGa_BTdE',
#  'bxsvryWeGxg',
#  'hn4RLVaIvHY',
#  'Qd4abX6DbDY',
#  'Y2_jA57VJFE',
#  'JIwzOool-9k',
#  '51KPDwZWgpw',
#  'nPkUMXv3Udw',
#  'FCOoyz0g8ro',
#  'vD-VE25YVPU',
#  'x9EnWTxEp5Q',
#  'kKNn48SfF2U',
#  'qh5LYUxQFWM',
#  'KJNhiphtXeI',
#  '0IdV0yo65Bo',
#  '2Q6m5Z3gWJo',
#  '-C4LoTh8Fwg',
#  '97lsxotdOY0',
#  'xVmQOqEjs4I',
#  'vTRBTctIJ_w',
#  'LmxZxl4qme4',
#  'jOqqKAD5Q0E',
#  'N3jPOXHcNds',
#  'JTcFZ5Ne3Js',
#  'wQpANpuKRsk',
#  'dkNI95p8pBE',
#  'WPDPIr1RfUs',
#  '64PeDK3SAWw',
#  'C5WrTYmFHCc',
#  'r5ko2HLnhTI',
#  'gK7maJranLg',
#  'mydHt4PqEXI',
#  'c5p1Tdd02sM',
#  'HHJzX0UerCY',
#  't5uRHi1GcVA',
#  'qdbX1NVPziM',
#  '9bvGi3g5mug',
#  'lE8Q78m5qJA',
#  'GXYTZsDseMs',
#  'eEAwqmpe6FY',
#  'NHv3VSga85k',
#  '8FIFIv_r8-Y',
#  'HhuXRoPaw8M',
#  'KFQHfmsPVlc',
#  'XDq5y_NkLg0',
#  'Gu54ruPOFdY',
#  'diTLW6KMDB0',
#  'TnumdzVdTz4',
#  'b3WDghJ0qYk',
#  'hSZil5SiYtc',
#  '43YhKg5HJD8',
#  'pZ4uiGJfjUg',
#  'BaJAjTLsc2I',
#  'R3oyyBO-3rE',
#  'NIFFewQs9R0',
#  '_nBgLisbnfU',
#  'omaMzyawKWg',
#  '39QMzRDJupY',
#  'BCUcx3TPV0g',
#  'M7CENW_yYBs',
#  'vkVjX5UpJQ8',
#  '2VoVCHCHJy8',
#  '66wLFTV9P20',
#  'ppk0RRk4Yok',
#  '64u31pPzkqI',
#  '0OZfI2Pm9TE',
#  'UjJHh9jlf4E',
#  'UmL0uw-rD-Y',
#  'i1d7qG5Y6cc',
#  'DlVo0C6Dm-M',
#  'E4A75_3pJJk',
#  'pw9sAj5XDUw',
#  'a6pDLjGEhv8',
#  '2yH7dYVcpGY',
#  'd25MDrKx91A',
#  'coAykhr-CtY',
#  'gBuwt49J7M8',
#  'vDrOm_KxPJE',
#  'y96t_7GaXvk',
#  'ekItfiNmy4g',
#  '6rVqgmdNCIo',
#  'w43AxRhQaGc',
#  'e1OVr3rW5hg',
#  'mYWXFlU_-_M',
#  'QGXmqcsELDE',
#  'nwqFUeUgVQU',
#  'qgsI6998ACw',
#  'gFqGcTbs33Q',
#  'W7wGfpeBKic',
#  'p488zMYBQNQ',
#  'lXStnrZh9tE',
#  'qPJMWoY-BWk',
#  'TkQoxCADfc8',
#  'OBV7ko0NS_c',
#  'r4GzXFV57lA',
#  '6JXpZTnKkI4',
#  'Uwq8SvkG-gU',
#  'TeWHf1mtThk',
#  'vTz2fg0JPGM',
#  '6jRWHc5tSCE',
#  'b5Z2QIq0PmI',
#  'SHRMNeHwNYM',
#  'vPV7k5iDHS8',
#  'VqNzFvdWdKY',
#  'wv3JlGlDBjo',
#  'DSUanbn3Mgg',
#  'Uee0CYrcn9A',
#  '2-agDa1fb3w',
#  'rhukLSlZVl8',
#  'jlClBoi9P8E',
#  'YOTMMR8yF0E',
#  'YQoEnSOiH8s',
#  '8hcRZHqSniE',
#  '3tolI3GsbW4',
#  'ixqXOheiyOU',
#  'zlIOEgxUgnU',
#  '0s0B-IAO4F0',
#  'onG-vlqwcWA',
#  'vDQkakMhEGM',
#  '78P9DZBNpSg',
#  'k1BB4c3fn1Y',
#  'BB3eIaj0MC8',
#  'qquQSdWoLwY',
#  'uiirJkQVRyc',
#  'coP88QlVd6g',
#  '7bUFHx9U0Fs',
#  'fFbE9Mxjxp0',
#  '-mlqSym8Ags',
#  'PpohBbzsH2g',
#  'DS2Pmbw2cMg',
#  'ziq-rufeHVs',
#  '0KEuTtcBmBU',
#  'qDP5GGfGHi8',
#  'Dy-D7C8K9K0',
#  'DBdvMUOFyI4',
#  'RYTgfaFGtVM',
#  'IoHhe4hwRDA',
#  'YpEyKSY_vPw',
#  'l_i2JaP-w90',
#  'EJHSHXe5gtM',
#  'gby-JrRLfJI',
#  '9NHRYtejdTI',
#  'gsDrRPsg-Jc',
#  '7PgOyhV42FY',
#  'dXn17i_pUlw',
#  'w4rnxbEoDt4',
#  'tFlDBSQmqng',
#  'mQbT-SKPWEo',
#  'RZ_MXWQTp2Y',
#  '9HX7CiROkBo',
#  'ptv8-1KGcPA',
#  'phTeXHOoaLw',
#  'uPqRWD4XOtk',
#  'hov8XtlCi5c',
#  'lgLGuLzLjpA',
#  'eZrAF1p5ue8',
#  'Ye9N2vYgvNE',
#  'FG8s5ap7kUw',
#  'kWiOapW8n2U',
#  'DtX-jXWGhkc',
#  'xeJvsNBjyTQ',
#  'MBPXcg8NmUI',
#  'etRhbrzbKiU',
#  '9bCIqqxORY8',
#  'D-fzAo2lhKk',
#  'HGXcE_rLqf0',
#  'jXRYdt6-Hmw',
#  'I4SYF8tY3s0',
#  'DldlB_u31t0',
#  'sCu3UMRdPGA',
#  'NTokek20Wdc',
#  'YZh5p6fUQtA',
#  'Pv74nU5-zAc',
#  'ARTQbqfOsic',
#  'ZnLcJ-aaXtc',
#  'AfT3WrQd45Q',
#  'yEa6-CtOLc4',
#  '8fi39XrA7js',
#  'AMxvBiXme4E',
#  'wQj3QVyQae8',
#  'Ri1Qc48U1Hk',
#  'P5auake6ruQ',
#  'PGcGXyhy-QA',
#  'E3f6Qv9NNCA',
#  '_KHp7uYhheI',
#  'ODLEdHYBjqg',
#  'MhXD64TGiG8',
#  'qnIUb8jtbgI',
#  '_XtRXk-N9k0',
#  'n2MSAJRRuc8',
#  'kWxLsO924Vg',
#  'mi7-Pi0SFa4',
#  'cMC2WOs7I5M',
#  '2BI_QCaGjVE',
#  'QevBUR561hE',
#  'YYqKmWQqt5c',
#  'hKc50e4dtjc',
#  'jRtfOnVt1Xo',
#  'SMeuNExa5Rg',
#  'lkdhnnY12bc',
#  'GomUIo1EfJ0',
#  'jgqQ-mrV0gM',
#  'DBHdgm97oIg',
#  '4JWYyxzPTeE',
#  'jJNDNIeh2-A',
#  '7jQdyMUC1xw',
#  'vYaO4jHFMUs',
#  'HHQjKipWoZs',
#  'z6kNZIvRMrQ',
#  'OtNdwTo4MaY',
#  'Xikdsk2n17s',
#  'KScK0TVPJi0',
#  'soMqjHM2cyI',
#  'mki-EilWPMY',
#  'V47IxsJhgB0',
#  '25SKtd-ZAvk',
#  'wdpcNjBl44Y',
#  'z11Hpn1O-F8',
#  'wxttvllz5I4',
#  'RTskYwASHLQ',
#  'OskKB0SQXxg',
#  '_jzF4AjhHdg',
#  'X1hcsHA6xyc',
#  'LFKZwNbxuPs',
#  'klF0lw0ecAo',
#  'jCWSPqW4JL0',
#  'KHvfgU-nFIE',
#  'EG5wug_z_-0',
#  'juFPDXdHvCE',
#  'GZaveFUY8Lo',
#  'OUqfEYoepx0',
#  'FVbMbX9L6_o',
#  'zEbbRTx9GWw',
#  '4yCFJgr6HYs',
#  'ui7V77y3Wew',
#  'NqXC2f3nAPg',
#  '3G7hEb9MQnc',
#  'rpNNN4v7D-E',
#  'rSR514zUz3Q',
#  'v5CHOzvxQIA',
#  '0ZQ-J3GxGm4',
#  'WR-SP92PnAk',
#  'NkPlj7q_-3Y',
#  '1-1ZSbTV3hg',
#  'DIK-HDgb4io',
#  'q556c6NPaHc',
#  'LpypKMdLZCc',
#  'KGuZUMIe4mk',
#  'eVPa0AaTamY',
#  'QbJyc9a5x8U',
#  'W3mlxzkKk9k',
#  'Bw0M6A5wWDA',
#  '8ufJYmFQAYA',
#  'I8Lgtpu6fZU',
#  '5H50lOM1yoc',
#  'W0SDLbbkxIY',
#  'olkjB-Udwd0',
#  'N0hPMqsb20M',
#  'TJnt0o0WaZo',
#  'fWWpzyRdbrM',
#  'JIYbrSxF4Ig',
#  '9Qoa4vn71Gc',
#  'RcoRiVeOegI',
#  'RKzJ5qYcVsw',
#  'y4RdylLWPlc',
#  'sbwDy4XDtEM',
#  '_GlSOQzpFj8',
#  'ABdcxPcDdyA',
#  'k9nIVql1XHw',
#  '-0BIukrmhSM',
#  '2FlJFnynNT0',
#  'JCS7xqRrJUk',
#  'I4RkmFit6BU',
#  'z0Lpm7f5y5M',
#  'xBJl0x10h5s',
#  '3Sm5mmuepfQ',
#  '0F4mkmIw7i4',
#  '3O4isvaftlU',
#  '0bHixa3UVeQ',
#  'A2BOR-mV83A',
#  'w81UQ8eWX-A',
#  'm9a7BYFi9e0',
#  'OCgj9VJb18g',
#  'E53DzvuStEY',
#  'gnNs-LdtxQg',
#  'OBbpgmlflhU',
#  'zSTZQFqK_oU',
#  'AU2IGCYWmC8',
#  'gLTtdV4xXd4',
#  '0IMf29VtuVA',
#  '3q_5L4DH3Pg',
#  '5GhhC7B36XM',
#  'uUgh2toKaSI',
#  '7cCPyoBtM_c',
#  'w7R-tZWm7F8',
#  'LvK-Jk0gPQY',
#  'Mjp12KJj_mo',
#  'YuLtpCuNhJw',
#  'to4Pt93VMMg',
#  'GN9zwFTZLyI',
#  'B4FR7fsErRU',
#  'DQIkzwu-cVE',
#  'RLdLv29cGow',
#  'Q-X1Ebz2d1s',
#  '5W7x9HGQnw4',
#  'PogUt2PU11U',
#  'wx9_M7KLEnk',
#  'tbHPFQcnYao',
#  'mS_hLNsIS_Q',
#  'oEiVhAwM9kI',
#  'rcMm5ykb508',
#  'OugXENWn63Y',
#  'Yoa-g9j7skQ',
#  'EIV9V3XqD9A',
#  'meUnfhoRUnY',
#  '4nnFolxppe8',
#  'tsqIhxumXOc',
#  'XhI8FfX_q-I',
#  'cGKkoH6enLM',
#  '_LjIF8Z6atU',
#  'RZHjMFAtfeQ',
#  'q-CUnLZUkx8',
#  '_V-obuMFIFY',
#  'xiRgFq0p-Mc',
#  'C9t9PtXxrdA',
#  '_9rovqShjKM',
#  '2mpVYLJv5bQ',
#  'ZCzto-qI7ao',
#  'gWrW4f2Rivw',
#  '_kQ9IpIupWo',
#  'eNkVjB_3ris',
#  'ahNuKrejFQY',
#  'HQBnjaDmmzQ',
#  'SPUTaS3nV6k',
#  'OKrJz7A23uc',
#  'x90wkkGMN8k',
#  '4_wExsilPqM',
#  'dZ48MJgzE9o',
#  'Z11fZkjSLl8',
#  'UEx2n2p2KXo',
#  'F9CIokRAp7I',
#  'at9bMhW99pI',
#  'GEBQiOx5h0Q',
#  'e3ORlRNUWhQ',
#  'RZFZePYpspw',
#  '1OPOAFFkjYU',
#  'ccpZ6O8CWoA',
#  'ARULXzUsdic',
#  'dvgMOGj0aB0',
#  '0OQ4lM-Q9Vs',
#  'bunYu8H7hu8',
#  '4j7HQNbm0f4',
#  'AfmoIRiWTa8',
#  '_6fTefIxZZg',
#  'LJmhZAU9MUU',
#  'ayreVJmy4cs',
#  'XhgW6_uYJok',
#  'Phko4ndZ1Oc',
#  'ieLVpI23YCM',
#  'FlmnkaH5DTc',
#  'slDLci_Kjjo',
#  'kssI1D-fOFU',
#  'xd4EzM3e1hE',
#  'zKUMsWE0nI8',
#  'j4PCcQWNPMI',
#  'DBGwHDfGPJ4',
#  '65a7t2c36K8',
#  '3qG-9y36ZZE',
#  'O9C_1WGjh4w',
#  '_gU75UBD3Aw',
#  '982gaLd3zvo',
#  'wnYLa_8B6ys',
#  'FOdiZuLET6g',
#  'UhvytaxJRxw',
#  '_RbPjfAQ5Qk',
#  'v_ENb-qOd04',
#  'v_j2ZdxmrEw',
#  '3L07bO3b7bA',
#  '_cPUzCFP3eI',
#  'yVBeCGfMyZk',
#  'YNXWBtRh2G4']

# %%
#get videos information
def get_video_info(video_ids):
    video_data=[]
    for video_ID in video_ids:
        request=youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=video_ID
        )
        response=request.execute()
        for i in response['items']:
            data=dict(Channel_Name=i['snippet']['channelTitle'],
                      Channel_Id=i['snippet']['channelId'],
                      Video_Id=i['id'],
                      Title=i['snippet']['title'],
                      #Tags=i['snippet'].get('tags'),
                      Thumbnail=i['snippet']['thumbnails']['default']['url'],
                      Comments=i['statistics'].get('commentCount'),
                      Like_Count=i['statistics'].get('likeCount'),
                      Dislike_Count=i['statistics'].get('dislikeCount'),
                      Faviorite=i['statistics']['favoriteCount'],
                      Description=i['snippet'].get('description'),
                      Published_Date=i['snippet']['publishedAt'],
                      Duration=i['contentDetails']['duration'],
                      Views=i['statistics'].get('viewCount'),
                      Definition=i['contentDetails']['definition'],
                      Caption_Status=i['contentDetails']['caption']
                      )
            video_data.append(data)
            
        return video_data

# %%
video_details=get_video_info(video_Ids) # video_ids previous output code
video_details
# Out:
# [{'Channel_Name': 'Colour of Dreams',
#   'Channel_Id': 'UCeQnqwVSQM8W0o1E5nWql2g',
#   'Video_Id': 'tUBnJODVsEg',
#   'Title': 'mehndi design for full hand || bhari hui haton wali mehandi ke design',
#   'Thumbnail': 'https://i.ytimg.com/vi/tUBnJODVsEg/default.jpg',
#   'Comments': '2',
#   'Like_Count': '23',
#   'Dislike_Count': None,
#   'Faviorite': '0',
#   'Description': 'mehndi design for full hand || bhari hui haton wali mehandi ke design\n\n\nMusic 🎵: Youtube Audio Library\n\nSocial Links:\nInstagram https://www.instagram.com/colour_ofdreams/\n\n\n#mehndidesigns \n#fullhandmehndi \n#mehandi',
#   'Published_Date': '2024-02-08T04:30:30Z',
#   'Duration': 'PT4M35S',
#   'Views': '762',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %%
#GETTING COMMENTS INFORMATION
def get_comment_info(video_ids):
    
    Comment_data=[]
    try:
        for video_id in video_ids:
            
            request=youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=50
            )
            response=request.execute()

            for i in response['items']:
                data=dict(Comment_Id=i['snippet']['topLevelComment']['id'],
                        Video_Id=i['snippet']['topLevelComment']['snippet']['videoId'],
                Comment_Text=i['snippet']['topLevelComment']['snippet']['textDisplay'],
                Comment_Author=i['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                Comment_Published=i['snippet']['topLevelComment']['snippet']['publishedAt'])
            
            
            Comment_data.append(data)
            
    except:
        pass
    return Comment_data

# %%
Comment_details=get_comment_info(video_Ids)
Comment_details
# Out:
# [{'Comment_Id': 'UgzayilnFo9qkNvecah4AaABAg',
#   'Video_Id': 'tUBnJODVsEg',
#   'Comment_Text': 'Nice maim ❤❤',
#   'Comment_Author': '@apalamehandiart',
#   'Comment_Published': '2024-02-09T00:02:10Z'},
#  {'Comment_Id': 'UgzayilnFo9qkNvecah4AaABAg',
#   'Video_Id': 'tUBnJODVsEg',
#   'Comment_Text': 'Nice maim ❤❤',
#   'Comment_Author': '@apalamehandiart',
#   'Comment_Published': '2024-02-09T00:02:10Z'},
#  {'Comment_Id': 'UgxSfvwK3h6h2K62rid4AaABAg',
#   'Video_Id': 'mlwvUOvls7E',
#   'Comment_Text': 'Nice',
#   'Comment_Author': '@aarav1028',
#   'Comment_Published': '2024-01-25T08:38:13Z'},
#  {'Comment_Id': 'UgxSfvwK3h6h2K62rid4AaABAg',
#   'Video_Id': 'mlwvUOvls7E',
#   'Comment_Text': 'Nice',
#   'Comment_Author': '@aarav1028',
#   'Comment_Published': '2024-01-25T08:38:13Z'},
#  {'Comment_Id': 'Ugx1a2KnMz9PXpRUBV54AaABAg',
#   'Video_Id': 'szlFqwBYPeQ',
#   'Comment_Text': 'Nice 😊👍👍',
#   'Comment_Author': '@iKittuhennaartist',
#   'Comment_Published': '2024-01-10T17:24:55Z'},
#  {'Comment_Id': 'Ugxqj911ovNt-H74Fzt4AaABAg',
#   'Video_Id': '4TYZx5midWQ',
#   'Comment_Text': 'First comment pls pin me ❤❤',
#   'Comment_Author': '@user-mc9hd7kk2y',
#   'Comment_Published': '2024-01-09T05:48:53Z'},
#  {'Comment_Id': 'Ugxqj911ovNt-H74Fzt4AaABAg',
#   'Video_Id': '4TYZx5midWQ',
#   'Comment_Text': 'First comment pls pin me ❤❤',
#   'Comment_Author': '@user-mc9hd7kk2y',
#   'Comment_Published': '2024-01-09T05:48:53Z'},
#  {'Comment_Id': 'Ugxqj911ovNt-H74Fzt4AaABAg',
#   'Video_Id': '4TYZx5midWQ',
#   'Comment_Text': 'First comment pls pin me ❤❤',
#   'Comment_Author': '@user-mc9hd7kk2y',
#   'Comment_Published': '2024-01-09T05:48:53Z'},
#  {'Comment_Id': 'UgyMvai9wE3FX_426kZ4AaABAg',
#   'Video_Id': 'gfel3Ij9yrI',
#   'Comment_Text': 'Very nice sis😍👌👍',
#   'Comment_Author': '@RealIndianArts',
#   'Comment_Published': '2024-01-05T04:50:02Z'},
#  {'Comment_Id': 'UgyMvai9wE3FX_426kZ4AaABAg',
#   'Video_Id': 'gfel3Ij9yrI',
#   'Comment_Text': 'Very nice sis😍👌👍',
#   'Comment_Author': '@RealIndianArts',
#   'Comment_Published': '2024-01-05T04:50:02Z'},
#  {'Comment_Id': 'UgzwJBup5nkSScNtSAh4AaABAg',
#   'Video_Id': '3yC1QSkJgl4',
#   'Comment_Text': 'Mast didi😊',
#   'Comment_Author': '@iKittuhennaartist',
#   'Comment_Published': '2023-12-27T12:41:43Z'},
#  {'Comment_Id': 'UgytmRRRHS78j6BqQbR4AaABAg',
#   'Video_Id': '2FjTLgAXAXA',
#   'Comment_Text': 'Nice 😊',
#   'Comment_Author': '@iKittuhennaartist',
#   'Comment_Published': '2023-12-25T16:41:00Z'},
#  {'Comment_Id': 'Ugy40I25DRERbXoeBLd4AaABAg',
#   'Video_Id': 'Ous2DXxlDPs',
#   'Comment_Text': 'Osm❤️❤️ I am second pin me',
#   'Comment_Author': '@priyalovelyworld1293',
#   'Comment_Published': '2023-12-23T05:59:31Z'},
#  {'Comment_Id': 'UgzmRBOvM8Bc4cw45Z54AaABAg',
#   'Video_Id': 'Qrcpr4aT8jQ',
#   'Comment_Text': 'Very nice design',
#   'Comment_Author': '@aaishamehandidesign1626',
#   'Comment_Published': '2023-12-21T15:46:45Z'},
#  {'Comment_Id': 'UgzmRBOvM8Bc4cw45Z54AaABAg',
#   'Video_Id': 'Qrcpr4aT8jQ',
#   'Comment_Text': 'Very nice design',
#   'Comment_Author': '@aaishamehandidesign1626',
#   'Comment_Published': '2023-12-21T15:46:45Z'},
#  {'Comment_Id': 'Ugzn_WUuFtdd3OHFCjR4AaABAg',
#   'Video_Id': 'Ro_7-a3tGeg',
#   'Comment_Text': '𝑺𝒐 𝒔𝒐 𝒔𝒐 𝒃𝒆𝒂𝒖𝒕𝒊𝒇𝒖𝒍❤❤',
#   'Comment_Author': '@prachisengupta',
#   'Comment_Published': '2023-12-11T06:59:40Z'},
#  {'Comment_Id': 'Ugz4QM5DDkGl844VFMd4AaABAg',
#   'Video_Id': 'l7myt96UR7w',
#   'Comment_Text': 'Nice',
#   'Comment_Author': '@Sk_Mehndi_Jabalpur',
#   'Comment_Published': '2023-12-06T04:30:39Z'},
#  {'Comment_Id': 'UgxpMedP0j6t-C4yA8x4AaABAg',
#   'Video_Id': 'qeVvVoird_c',
#   'Comment_Text': 'Wow so beautiful design',
#   'Comment_Author': '@user-mb8mh5cd3d',
#   'Comment_Published': '2023-12-03T04:41:37Z'},
#  {'Comment_Id': 'UgyewVaeS5C5tx9Ibt54AaABAg',
#   'Video_Id': '0Yx-5dyWqE8',
#   'Comment_Text': '❤❤',
#   'Comment_Author': '@shubhgeetmala9191',
#   'Comment_Published': '2023-12-02T08:14:10Z'},
#  {'Comment_Id': 'UgzQhi0DFqVHfZZI75x4AaABAg',
#   'Video_Id': 'oLFo01E1fw0',
#   'Comment_Text': 'Very beautiful',
#   'Comment_Author': '@Sk_Mehndi_Jabalpur',
#   'Comment_Published': '2023-11-16T05:16:54Z'},
#  {'Comment_Id': 'UgwhUQS6BVQNOCm0uU94AaABAg',
#   'Video_Id': 'sGGGVAo_wGo',
#   'Comment_Text': 'I love this your mehandi designs❤❤',
#   'Comment_Author': '@KhushiYadav-dx9wc',
#   'Comment_Published': '2023-11-11T04:35:24Z'},
#  {'Comment_Id': 'UgyFClPXOXA9to7GR954AaABAg',
#   'Video_Id': 'mg-C0L1X_IY',
#   'Comment_Text': 'Aap thumbnail kis app se edit karte hai???',
#   'Comment_Author': '@TheBhauOfficiall',
#   'Comment_Published': '2023-11-09T07:19:40Z'},
#  {'Comment_Id': 'Ugw96dHn4YC97fwB1yZ4AaABAg',
#   'Video_Id': 'AyKiyW2bMnU',
#   'Comment_Text': 'Beautiful',
#   'Comment_Author': '@Sk_Mehndi_Jabalpur',
#   'Comment_Published': '2023-10-31T05:02:32Z'},
#  {'Comment_Id': 'UgxxEica4iZp0NnAG-B4AaABAg',
#   'Video_Id': 'Yse-0YVOc3o',
#   'Comment_Text': 'Very nice 👍',
#   'Comment_Author': '@bindusingh6798',
#   'Comment_Published': '2023-10-26T04:40:48Z'},
#  {'Comment_Id': 'UgyMAfgIx1d5Q7pCyX14AaABAg',
#   'Video_Id': 'z1jfHr58VpE',
#   'Comment_Text': 'Beautiful ❤❤❤',
#   'Comment_Author': '@NKART139',
#   'Comment_Published': '2023-10-20T09:38:32Z'},
#  {'Comment_Id': 'UgxOgQ-7Y78qIdVZCO94AaABAg',
#   'Video_Id': 'WWsNA0xKK9w',
#   'Comment_Text': 'Beautiful',
#   'Comment_Author': '@Sk_Mehndi_Jabalpur',
#   'Comment_Published': '2023-10-18T06:50:53Z'},
#  {'Comment_Id': 'UgzVT1cKEGWrspmjYbh4AaABAg',
#   'Video_Id': 'rAFgtgbw710',
#   'Comment_Text': '👌🏻',
#   'Comment_Author': '@Sk_Mehndi_Jabalpur',
#   'Comment_Published': '2023-10-16T05:27:51Z'},
#  {'Comment_Id': 'UgzjQFjyuNhXjrjoaNB4AaABAg',
#   'Video_Id': 'jo6Dt4R8dmU',
#   'Comment_Text': 'Mere liye bus ek br bell lga ke ek video upload krdo plz didi plz 😢🙏',
#   'Comment_Author': '@nainamolla4613',
#   'Comment_Published': '2023-10-15T16:45:02Z'},
#  {'Comment_Id': 'Ugyb2E2xQyK4RdMgtOZ4AaABAg',
#   'Video_Id': 'ZC2-olAtgrM',
#   'Comment_Text': '❤❤❤ perfectly designed',
#   'Comment_Author': '@samekshapankhuri7209',
#   'Comment_Published': '2023-10-13T05:30:08Z'},
#  {'Comment_Id': 'UgwKh7tctt0M12fxEzx4AaABAg',
#   'Video_Id': 'hPmOyWgae8I',
#   'Comment_Text': 'Hello',
#   'Comment_Author': '@SatyamKumar-jt8cj',
#   'Comment_Published': '2023-10-11T05:44:58Z'},
#  {'Comment_Id': 'UgwKh7tctt0M12fxEzx4AaABAg',
#   'Video_Id': 'hPmOyWgae8I',
#   'Comment_Text': 'Hello',
#   'Comment_Author': '@SatyamKumar-jt8cj',
#   'Comment_Published': '2023-10-11T05:44:58Z'},
#  {'Comment_Id': 'UgysfsdfZF1JorcDpJd4AaABAg',
#   'Video_Id': 'YaFe2dlHoQc',
#   'Comment_Text': 'Wow🤗🤗',
#   'Comment_Author': '@mayarammayaramkanojiya6165',
#   'Comment_Published': '2023-10-07T15:26:31Z'},
#  {'Comment_Id': 'UgxWjYd068vrfoGX_kJ4AaABAg',
#   'Video_Id': 'JIIXJdEzQp8',
#   'Comment_Text': 'HAI',
#   'Comment_Author': '@harish.8501',
#   'Comment_Published': '2023-10-04T04:42:16Z'},
#  {'Comment_Id': 'UgwEFgJK4gkTVT8W_3d4AaABAg',
#   'Video_Id': 'X2YGpikKF3o',
#   'Comment_Text': 'Very beautiful design dear 🥰 first comment 🎉',
#   'Comment_Author': '@cutiemehendiart',
#   'Comment_Published': '2023-10-01T06:45:26Z'},
#  {'Comment_Id': 'UgwEFgJK4gkTVT8W_3d4AaABAg',
#   'Video_Id': 'X2YGpikKF3o',
#   'Comment_Text': 'Very beautiful design dear 🥰 first comment 🎉',
#   'Comment_Author': '@cutiemehendiart',
#   'Comment_Published': '2023-10-01T06:45:26Z'},
#  {'Comment_Id': 'UgwUnfkPmXdgSaaeVwV4AaABAg',
#   'Video_Id': 'k2FIzUXflRI',
#   'Comment_Text': '👌🏻',
#   'Comment_Author': '@Sk_Mehndi_Jabalpur',
#   'Comment_Published': '2023-09-24T05:29:02Z'},
#  {'Comment_Id': 'UgzzyUD9X4Mlm53a-NF4AaABAg',
#   'Video_Id': '3caaqu9hH48',
#   'Comment_Text': 'Super 🎉🎉🎉',
#   'Comment_Author': '@ekta8962',
#   'Comment_Published': '2023-09-21T04:34:46Z'},
#  {'Comment_Id': 'Ugym21y6T5IDRvmF7xR4AaABAg',
#   'Video_Id': 'F_stDXo6q_A',
#   'Comment_Text': 'Ashish',
#   'Comment_Author': '@user-dw3dq2dc5k',
#   'Comment_Published': '2023-09-24T14:40:12Z'},
#  {'Comment_Id': 'UgyJN8y2WaaSA2gXOdR4AaABAg',
#   'Video_Id': 'pq8V8DrN00E',
#   'Comment_Text': 'Beautiful design  and very easy',
#   'Comment_Author': '@shamlakhan3202',
#   'Comment_Published': '2023-09-16T04:40:52Z'},
#  {'Comment_Id': 'UgyJN8y2WaaSA2gXOdR4AaABAg',
#   'Video_Id': 'pq8V8DrN00E',
#   'Comment_Text': 'Beautiful design  and very easy',
#   'Comment_Author': '@shamlakhan3202',
#   'Comment_Published': '2023-09-16T04:40:52Z'},
#  {'Comment_Id': 'UgyTN4mL8LLCT5uWQfB4AaABAg',
#   'Video_Id': 'y1y8LlJHRiw',
#   'Comment_Text': 'Very nice',
#   'Comment_Author': '@anushkapotdar5797',
#   'Comment_Published': '2023-09-19T15:58:10Z'},
#  {'Comment_Id': 'UgymvfkyGUQGAUtzSKp4AaABAg',
#   'Video_Id': '93YAE0dKnqo',
#   'Comment_Text': 'Beautiful',
#   'Comment_Author': '@Sk_Mehndi_Jabalpur',
#   'Comment_Published': '2023-09-08T04:38:59Z'},
#  {'Comment_Id': 'UgymvfkyGUQGAUtzSKp4AaABAg',
#   'Video_Id': '93YAE0dKnqo',
#   'Comment_Text': 'Beautiful',
#   'Comment_Author': '@Sk_Mehndi_Jabalpur',
#   'Comment_Published': '2023-09-08T04:38:59Z'},
#  {'Comment_Id': 'Ugx2ciH6Zn8RmmXeRPd4AaABAg',
#   'Video_Id': 'vWy7m02yPHQ',
#   'Comment_Text': 'Nice',
#   'Comment_Author': '@its503',
#   'Comment_Published': '2023-08-30T08:36:56Z'},
#  {'Comment_Id': 'Ugz03I0EyEm4bk2b6oZ4AaABAg',
#   'Video_Id': 'zmI3alwB_p4',
#   'Comment_Text': '😊😊',
#   'Comment_Author': '@ayonff134',
#   'Comment_Published': '2023-08-27T04:38:10Z'},
#  {'Comment_Id': 'UgxchZWui4s-oNCm2kh4AaABAg',
#   'Video_Id': 'bYm3XedadHw',
#   'Comment_Text': '5like beautiful design dear',
#   'Comment_Author': '@mitalisfoodzone490',
#   'Comment_Published': '2023-08-25T04:47:20Z'},
#  {'Comment_Id': 'UgzUWQPl8ch2nEv_LsN4AaABAg',
#   'Video_Id': 'Mjz046oRClg',
#   'Comment_Text': 'Waw di aap kitni achchhi mehandi lgati ho hayeeeeeeeee ❤',
#   'Comment_Author': '@user-ih2bk1ip1i',
#   'Comment_Published': '2023-08-22T05:17:30Z'},
#  {'Comment_Id': 'UgyyOGdrcW05ism56ql4AaABAg',
#   'Video_Id': 'R2uPcXYWHkw',
#   'Comment_Text': '❤❤❤❤❤❤',
#   'Comment_Author': '@kumarsah1699',
#   'Comment_Published': '2023-08-19T05:44:55Z'},
#  {'Comment_Id': 'UgymtR7_nfpFGGZkfJV4AaABAg',
#   'Video_Id': 'B1ebUIMD5vY',
#   'Comment_Text': 'Nice❤',
#   'Comment_Author': '@AjabSingh-nh7ul',
#   'Comment_Published': '2023-08-18T14:28:13Z'},
#  {'Comment_Id': 'UgygLgQ3CYtX1Vu4lMx4AaABAg',
#   'Video_Id': 'TeGJighTm9E',
#   'Comment_Text': 'Waw so beautiful mehandi ❤',
#   'Comment_Author': '@user-ih2bk1ip1i',
#   'Comment_Published': '2023-08-15T04:32:00Z'},
#  {'Comment_Id': 'UgyY7iOIzxYpXpFZaXl4AaABAg',
#   'Video_Id': 'df7rCAgtazg',
#   'Comment_Text': '😮',
#   'Comment_Author': '@Bhargavi-ew9fj',
#   'Comment_Published': '2023-08-25T15:33:23Z'},
#  {'Comment_Id': 'UgyY7iOIzxYpXpFZaXl4AaABAg',
#   'Video_Id': 'df7rCAgtazg',
#   'Comment_Text': '😮',
#   'Comment_Author': '@Bhargavi-ew9fj',
#   'Comment_Published': '2023-08-25T15:33:23Z'},
#  {'Comment_Id': 'UgyocUM27e70VzuEnax4AaABAg',
#   'Video_Id': 'hKMK8CgOoK4',
#   'Comment_Text': 'Beautiful design',
#   'Comment_Author': '@Sk_Mehndi_Jabalpur',
#   'Comment_Published': '2023-08-09T06:04:06Z'},
#  {'Comment_Id': 'UgxJ86nQ9Rvqs5cD5Sd4AaABAg',
#   'Video_Id': 'j9cX8XCBoAM',
#   'Comment_Text': 'Wow beautiful😍',
#   'Comment_Author': '@Sk_Mehndi_Jabalpur',
#   'Comment_Published': '2023-08-07T06:54:03Z'},
#  {'Comment_Id': 'UgxJ86nQ9Rvqs5cD5Sd4AaABAg',
#   'Video_Id': 'j9cX8XCBoAM',
#   'Comment_Text': 'Wow beautiful😍',
#   'Comment_Author': '@Sk_Mehndi_Jabalpur',
#   'Comment_Published': '2023-08-07T06:54:03Z'},
#  {'Comment_Id': 'UgwhR7cwl4NiB3msEgN4AaABAg',
#   'Video_Id': 'fb2K5x1yiX8',
#   'Comment_Text': 'Hlo mam ye mehdi ki keep market  wali h ya apne aap bnate ho please reply 😊',
#   'Comment_Author': '@ushasahu6283',
#   'Comment_Published': '2023-08-03T05:03:46Z'},
#  {'Comment_Id': 'UgwhR7cwl4NiB3msEgN4AaABAg',
#   'Video_Id': 'fb2K5x1yiX8',
#   'Comment_Text': 'Hlo mam ye mehdi ki keep market  wali h ya apne aap bnate ho please reply 😊',
#   'Comment_Author': '@ushasahu6283',
#   'Comment_Published': '2023-08-03T05:03:46Z'},
#  {'Comment_Id': 'UgzYJKhYi4Chdj1r0cd4AaABAg',
#   'Video_Id': 'uiSn6iW_IMc',
#   'Comment_Text': 'Beautiful design dear sister 🥰❤️😍 Beautiful',
#   'Comment_Author': '@cutiemehendiart',
#   'Comment_Published': '2023-07-31T05:33:21Z'},
#  {'Comment_Id': 'UgyyWYqMrX7QMXfizsN4AaABAg',
#   'Video_Id': 'TOffBUlhOGA',
#   'Comment_Text': '𝙽𝚒𝚌𝚎',
#   'Comment_Author': '@rameshnicesister296',
#   'Comment_Published': '2023-07-29T04:32:01Z'},
#  {'Comment_Id': 'UgzD0YFcUHXnQ36fAfl4AaABAg',
#   'Video_Id': 'Z5G9k58Go5o',
#   'Comment_Text': 'Ada designpora kro',
#   'Comment_Author': '@-55_ShauryaRana',
#   'Comment_Published': '2023-09-07T09:00:37Z'},
#  {'Comment_Id': 'Ugx_VdkJR5SxJcIeZ-94AaABAg',
#   'Video_Id': '3F4TYhdrk28',
#   'Comment_Text': 'Wow❤',
#   'Comment_Author': '@Meriduniya95438',
#   'Comment_Published': '2023-07-27T04:36:13Z'},
#  {'Comment_Id': 'UgzzzivQZDjoQbqL--B4AaABAg',
#   'Video_Id': 'pAjFV5yBZRk',
#   'Comment_Text': 'Cute design',
#   'Comment_Author': '@s.forsalwa8312',
#   'Comment_Published': '2023-07-26T04:59:29Z'},
#  {'Comment_Id': 'UgzzzivQZDjoQbqL--B4AaABAg',
#   'Video_Id': 'pAjFV5yBZRk',
#   'Comment_Text': 'Cute design',
#   'Comment_Author': '@s.forsalwa8312',
#   'Comment_Published': '2023-07-26T04:59:29Z'},
#  {'Comment_Id': 'UgyJMH2ZI1UWiwStpz54AaABAg',
#   'Video_Id': 'TNgRQaPx0co',
#   'Comment_Text': 'Apnar category ta ektu bolun apu',
#   'Comment_Author': '@Zoyablogs...9971',
#   'Comment_Published': '2023-07-24T05:02:12Z'},
#  {'Comment_Id': 'UgztHjeJqClJ7K2oMu14AaABAg',
#   'Video_Id': 'o1FY94cczE4',
#   'Comment_Text': 'Muje aapke mehndi designs bhut jadha pasnd aati hai thanku so much mam',
#   'Comment_Author': '@anuradhamaurya401',
#   'Comment_Published': '2023-09-14T15:08:17Z'},
#  {'Comment_Id': 'Ugzwud4N5r-ESiNdJl14AaABAg',
#   'Video_Id': 'lWMYwWLsO8A',
#   'Comment_Text': 'Wow😮❤❤',
#   'Comment_Author': '@golamkibria4298',
#   'Comment_Published': '2023-07-21T04:46:05Z'},
#  {'Comment_Id': 'Ugzwud4N5r-ESiNdJl14AaABAg',
#   'Video_Id': 'lWMYwWLsO8A',
#   'Comment_Text': 'Wow😮❤❤',
#   'Comment_Author': '@golamkibria4298',
#   'Comment_Published': '2023-07-21T04:46:05Z'},
#  {'Comment_Id': 'Ugy3u3_5lTce5RDSE194AaABAg',
#   'Video_Id': 'Dy8UYdD2lmE',
#   'Comment_Text': 'Very nice 👌 Design',
#   'Comment_Author': '@GeetanjaliChavan937',
#   'Comment_Published': '2023-09-29T11:38:12Z'},
#  {'Comment_Id': 'UgwmQJtIVqIKO18n1VR4AaABAg',
#   'Video_Id': 'iehGP44hg-I',
#   'Comment_Text': 'Your design are always amazing 👍😍😍',
#   'Comment_Author': '@roopmehndiarts9822',
#   'Comment_Published': '2023-07-12T12:05:30Z'},
#  {'Comment_Id': 'UgwmQJtIVqIKO18n1VR4AaABAg',
#   'Video_Id': 'iehGP44hg-I',
#   'Comment_Text': 'Your design are always amazing 👍😍😍',
#   'Comment_Author': '@roopmehndiarts9822',
#   'Comment_Published': '2023-07-12T12:05:30Z'},
#  {'Comment_Id': 'UgwmQJtIVqIKO18n1VR4AaABAg',
#   'Video_Id': 'iehGP44hg-I',
#   'Comment_Text': 'Your design are always amazing 👍😍😍',
#   'Comment_Author': '@roopmehndiarts9822',
#   'Comment_Published': '2023-07-12T12:05:30Z'},
#  {'Comment_Id': 'UgxLN141-UbpBs3NEeB4AaABAg',
#   'Video_Id': '9jO9gYbq4wM',
#   'Comment_Text': 'Osm😍',
#   'Comment_Author': '@shahbazsiddiqui5576',
#   'Comment_Published': '2023-07-07T04:38:02Z'},
#  {'Comment_Id': 'UgxLN141-UbpBs3NEeB4AaABAg',
#   'Video_Id': '9jO9gYbq4wM',
#   'Comment_Text': 'Osm😍',
#   'Comment_Author': '@shahbazsiddiqui5576',
#   'Comment_Published': '2023-07-07T04:38:02Z'},
#  {'Comment_Id': 'UgxYHtGAtS97LUBwgbd4AaABAg',
#   'Video_Id': '1esUzWzs2qY',
#   'Comment_Text': 'New letest design upload on my new YouTube channel <a href="http://www.youtube.com/results?search_query=%23mehndibyinshakhan2844">#mehndibyinshakhan2844</a>',
#   'Comment_Author': '@inshakhan6241',
#   'Comment_Published': '2023-07-05T19:13:58Z'},
#  {'Comment_Id': 'UgxYHtGAtS97LUBwgbd4AaABAg',
#   'Video_Id': '1esUzWzs2qY',
#   'Comment_Text': 'New letest design upload on my new YouTube channel <a href="http://www.youtube.com/results?search_query=%23mehndibyinshakhan2844">#mehndibyinshakhan2844</a>',
#   'Comment_Author': '@inshakhan6241',
#   'Comment_Published': '2023-07-05T19:13:58Z'},
#  {'Comment_Id': 'Ugxwr2IcTPOasewOlep4AaABAg',
#   'Video_Id': 'PIIUOrgHDx0',
#   'Comment_Text': 'Super 👍',
#   'Comment_Author': '@faridabegum1724',
#   'Comment_Published': '2023-06-17T05:27:09Z'},
#  {'Comment_Id': 'Ugxwr2IcTPOasewOlep4AaABAg',
#   'Video_Id': 'PIIUOrgHDx0',
#   'Comment_Text': 'Super 👍',
#   'Comment_Author': '@faridabegum1724',
#   'Comment_Published': '2023-06-17T05:27:09Z'},
#  {'Comment_Id': 'UgzOau4Le3GxtwgbVQB4AaABAg',
#   'Video_Id': 'lnuF_i_w1Vs',
#   'Comment_Text': 'Simple Mehndi tips',
#   'Comment_Author': '@arunchalam6905',
#   'Comment_Published': '2023-06-11T05:30:47Z'},
#  {'Comment_Id': 'UgwqiRFPJXgDpQk3zKB4AaABAg',
#   'Video_Id': 'sV0mkSBaykY',
#   'Comment_Text': 'Wowwww beautiful menhdi design 👌👌👌👌',
#   'Comment_Author': '@punjeebaranwal7399',
#   'Comment_Published': '2023-06-09T04:37:51Z'},
#  {'Comment_Id': 'UgwqiRFPJXgDpQk3zKB4AaABAg',
#   'Video_Id': 'sV0mkSBaykY',
#   'Comment_Text': 'Wowwww beautiful menhdi design 👌👌👌👌',
#   'Comment_Author': '@punjeebaranwal7399',
#   'Comment_Published': '2023-06-09T04:37:51Z'},
#  {'Comment_Id': 'UgwqiRFPJXgDpQk3zKB4AaABAg',
#   'Video_Id': 'sV0mkSBaykY',
#   'Comment_Text': 'Wowwww beautiful menhdi design 👌👌👌👌',
#   'Comment_Author': '@punjeebaranwal7399',
#   'Comment_Published': '2023-06-09T04:37:51Z'},
#  {'Comment_Id': 'UgywVnPHDrEp66qkzKh4AaABAg',
#   'Video_Id': 'lEvcbWmwviM',
#   'Comment_Text': 'Full video please',
#   'Comment_Author': '@rudrakshsahu3736',
#   'Comment_Published': '2023-06-07T13:10:43Z'},
#  {'Comment_Id': 'Ugy3WMpkYd90Gdu_DVd4AaABAg',
#   'Video_Id': '5kLN7uEPAFI',
#   'Comment_Text': 'Nice design..',
#   'Comment_Author': '@yeslileenaangelena2834',
#   'Comment_Published': '2023-06-02T04:43:54Z'},
#  {'Comment_Id': 'UgxCN28HO8-kG624Bvx4AaABAg',
#   'Video_Id': 'kZ8TWbkMYsw',
#   'Comment_Text': 'Beautiful😍✨',
#   'Comment_Author': '@sketchultimate1538',
#   'Comment_Published': '2023-05-28T05:25:55Z'},
#  {'Comment_Id': 'UgxCN28HO8-kG624Bvx4AaABAg',
#   'Video_Id': 'kZ8TWbkMYsw',
#   'Comment_Text': 'Beautiful😍✨',
#   'Comment_Author': '@sketchultimate1538',
#   'Comment_Published': '2023-05-28T05:25:55Z'},
#  {'Comment_Id': 'UgyMJr3buBCkAB6530J4AaABAg',
#   'Video_Id': 'UlG7EyFUQXg',
#   'Comment_Text': 'Aprtim Khup chan',
#   'Comment_Author': '@mangeshkhambe1177',
#   'Comment_Published': '2023-05-22T04:34:28Z'},
#  {'Comment_Id': 'UgyATaeyvBuN3dFNHw54AaABAg',
#   'Video_Id': 'Mts_in7jiF4',
#   'Comment_Text': 'Your new subscriber friend ❤',
#   'Comment_Author': '@sweetharapriya6974',
#   'Comment_Published': '2023-05-18T16:48:47Z'},
#  {'Comment_Id': 'UgwGeOBwTw3uGOU0ds94AaABAg',
#   'Video_Id': '8B5BBGN15Nw',
#   'Comment_Text': 'Sahi me mast',
#   'Comment_Author': '@AtharhjaSekh-vj9xu',
#   'Comment_Published': '2023-05-15T04:31:09Z'},
#  {'Comment_Id': 'UgyaaYUTRBxUn_tzsUN4AaABAg',
#   'Video_Id': 'GckxyFZQ6JI',
#   'Comment_Text': '❤',
#   'Comment_Author': '@sweetla536',
#   'Comment_Published': '2023-05-13T05:20:37Z'},
#  {'Comment_Id': 'UgyaaYUTRBxUn_tzsUN4AaABAg',
#   'Video_Id': 'GckxyFZQ6JI',
#   'Comment_Text': '❤',
#   'Comment_Author': '@sweetla536',
#   'Comment_Published': '2023-05-13T05:20:37Z'},
#  {'Comment_Id': 'UgyeugdspeQ5kQPOvlJ4AaABAg',
#   'Video_Id': '9sCQn-S-uYs',
#   'Comment_Text': 'Super 👌',
#   'Comment_Author': '@ibrahimibur1776',
#   'Comment_Published': '2023-05-06T04:35:02Z'},
#  {'Comment_Id': 'UgyeugdspeQ5kQPOvlJ4AaABAg',
#   'Video_Id': '9sCQn-S-uYs',
#   'Comment_Text': 'Super 👌',
#   'Comment_Author': '@ibrahimibur1776',
#   'Comment_Published': '2023-05-06T04:35:02Z'},
#  {'Comment_Id': 'Ugxg_RsSOxN8rzaN4Hh4AaABAg',
#   'Video_Id': 'RQX7hvWjbxQ',
#   'Comment_Text': 'It&#39;s so pretty design',
#   'Comment_Author': '@wahim5908',
#   'Comment_Published': '2023-06-07T14:50:59Z'},
#  {'Comment_Id': 'Ugxg_RsSOxN8rzaN4Hh4AaABAg',
#   'Video_Id': 'RQX7hvWjbxQ',
#   'Comment_Text': 'It&#39;s so pretty design',
#   'Comment_Author': '@wahim5908',
#   'Comment_Published': '2023-06-07T14:50:59Z'},
#  {'Comment_Id': 'Ugz4TVCuvY8w4JyoAo14AaABAg',
#   'Video_Id': 'A0aESfUlF3M',
#   'Comment_Text': 'Very simple and easy Design 👌',
#   'Comment_Author': '@geetmehandicreation8537',
#   'Comment_Published': '2023-04-28T15:58:05Z'},
#  {'Comment_Id': 'UgytkN0WW2XTndYCRC94AaABAg',
#   'Video_Id': 'QAkgGa_BTdE',
#   'Comment_Text': 'So beautiful design',
#   'Comment_Author': '@rahinimehndicreation5169',
#   'Comment_Published': '2023-04-27T02:07:06Z'},
#  {'Comment_Id': 'UgytkN0WW2XTndYCRC94AaABAg',
#   'Video_Id': 'QAkgGa_BTdE',
#   'Comment_Text': 'So beautiful design',
#   'Comment_Author': '@rahinimehndicreation5169',
#   'Comment_Published': '2023-04-27T02:07:06Z'},
#  {'Comment_Id': 'UgwqUn7bP_TTp5_6vg54AaABAg',
#   'Video_Id': 'hn4RLVaIvHY',
#   'Comment_Text': 'Won nice design',
#   'Comment_Author': '@browngirl1953',
#   'Comment_Published': '2023-04-21T07:01:43Z'},
#  {'Comment_Id': 'UgxFlOkCoZpslUL84JF4AaABAg',
#   'Video_Id': 'Qd4abX6DbDY',
#   'Comment_Text': 'super',
#   'Comment_Author': '@harish.8501',
#   'Comment_Published': '2023-04-14T05:44:25Z'},
#  {'Comment_Id': 'UgxFlOkCoZpslUL84JF4AaABAg',
#   'Video_Id': 'Qd4abX6DbDY',
#   'Comment_Text': 'super',
#   'Comment_Author': '@harish.8501',
#   'Comment_Published': '2023-04-14T05:44:25Z'},
#  {'Comment_Id': 'Ugw1QWJ7h9bE0TZmtVJ4AaABAg',
#   'Video_Id': 'JIwzOool-9k',
#   'Comment_Text': 'Wow yrr di❤.di plz aise hi simple simple design banao mai roj practice karti hu apki help se',
#   'Comment_Author': '@rachnasingh673',
#   'Comment_Published': '2023-03-20T06:35:59Z'},
#  {'Comment_Id': 'UgzUgGe-ulDIzgk3pI14AaABAg',
#   'Video_Id': '51KPDwZWgpw',
#   'Comment_Text': 'Very nice design 👌😍',
#   'Comment_Author': '@MithilasMehndiCorner',
#   'Comment_Published': '2023-03-12T14:00:47Z'},
#  {'Comment_Id': 'Ugz_tiBHXSMRir3-prp4AaABAg',
#   'Video_Id': 'nPkUMXv3Udw',
#   'Comment_Text': 'Nice design ❤️',
#   'Comment_Author': '@alartsforu',
#   'Comment_Published': '2023-03-09T15:18:42Z'},
#  {'Comment_Id': 'UgxpUZSwoWLYoGY7jXF4AaABAg',
#   'Video_Id': 'FCOoyz0g8ro',
#   'Comment_Text': 'mehndi ❤️🔥',
#   'Comment_Author': '@fast_mehndi2.0',
#   'Comment_Published': '2023-02-16T05:05:22Z'},
#  {'Comment_Id': 'UgyHj8CsC4ex4Oq9QXd4AaABAg',
#   'Video_Id': 'vD-VE25YVPU',
#   'Comment_Text': 'Per month encome',
#   'Comment_Author': '@user-iq1ll8zj4r',
#   'Comment_Published': '2023-02-14T07:36:04Z'},
#  {'Comment_Id': 'UgzWleGmku-iK8kVfn14AaABAg',
#   'Video_Id': 'x9EnWTxEp5Q',
#   'Comment_Text': 'Good mehndi design',
#   'Comment_Author': '@yahoomehendiarts',
#   'Comment_Published': '2023-02-11T17:18:29Z'},
#  {'Comment_Id': 'UgxaNP0rNR7ECkO-CTx4AaABAg',
#   'Video_Id': 'kKNn48SfF2U',
#   'Comment_Text': 'Achhii lgii nice ❤️',
#   'Comment_Author': '@vini3483',
#   'Comment_Published': '2023-02-08T04:51:29Z'},
#  {'Comment_Id': 'UgxyORd7ozYo1VhcKoJ4AaABAg',
#   'Video_Id': 'qh5LYUxQFWM',
#   'Comment_Text': 'ट',
#   'Comment_Author': '@anilbagul7017',
#   'Comment_Published': '2023-03-11T08:17:24Z'},
#  {'Comment_Id': 'Ugzv6dcaiUFPZEjkD2p4AaABAg',
#   'Video_Id': 'KJNhiphtXeI',
#   'Comment_Text': 'Plz sis meri bhi video dekh kr btayiye kaisi h',
#   'Comment_Author': '@pankhudivikkuofficial7667',
#   'Comment_Published': '2023-01-23T04:43:34Z'},
#  {'Comment_Id': 'UgxbUkkwL4ILxGtNukJ4AaABAg',
#   'Video_Id': '0IdV0yo65Bo',
#   'Comment_Text': 'it&#39;s beautiful',
#   'Comment_Author': '@missanacrochetpatterns3629',
#   'Comment_Published': '2023-01-06T19:40:43Z'},
#  {'Comment_Id': 'UgxR0noCC9xGSkiYLD54AaABAg',
#   'Video_Id': '2Q6m5Z3gWJo',
#   'Comment_Text': 'Nice next time full hand ✋ meandi desine plss',
#   'Comment_Author': '@rahulsingla744',
#   'Comment_Published': '2022-12-18T06:03:23Z'},
#  {'Comment_Id': 'Ugz5ejB9oiOtOWP2Ltd4AaABAg',
#   'Video_Id': '-C4LoTh8Fwg',
#   'Comment_Text': 'Best wishes for your effort',
#   'Comment_Author': '@divyask619',
#   'Comment_Published': '2022-12-04T05:14:04Z'},
#  {'Comment_Id': 'UgxOalhhkMGJEtZXl4J4AaABAg',
#   'Video_Id': '97lsxotdOY0',
#   'Comment_Text': 'Very Beautiful design dear friend 👌👌🥰',
#   'Comment_Author': '@cutiemehendiart',
#   'Comment_Published': '2022-11-27T05:24:57Z'},
#  {'Comment_Id': 'Ugyf1Lp4K3j_ofU8pHd4AaABAg',
#   'Video_Id': 'xVmQOqEjs4I',
#   'Comment_Text': 'Wow so beautiful stay connected',
#   'Comment_Author': '@MehndiExperiment',
#   'Comment_Published': '2022-11-21T06:11:50Z'},
#  {'Comment_Id': 'Ugz4Kku3S6Ubzsa44z14AaABAg',
#   'Video_Id': 'vTRBTctIJ_w',
#   'Comment_Text': 'Plz mention your mehendi name',
#   'Comment_Author': '@mahmudaeti5331',
#   'Comment_Published': '2022-11-20T11:07:33Z'},
#  {'Comment_Id': 'UgwtFUIo7ygsJYF3qrZ4AaABAg',
#   'Video_Id': 'LmxZxl4qme4',
#   'Comment_Text': 'Good ❤️❤️',
#   'Comment_Author': '@vini3483',
#   'Comment_Published': '2022-11-17T04:52:04Z'},
#  {'Comment_Id': 'UgzAAsGkiCJ8kIWb6dl4AaABAg',
#   'Video_Id': 'jOqqKAD5Q0E',
#   'Comment_Text': 'Beautiful 😍',
#   'Comment_Author': '@kavita_mehndi_art',
#   'Comment_Published': '2022-11-15T06:23:58Z'},
#  {'Comment_Id': 'UgyBNVGCYhFtSfdubBx4AaABAg',
#   'Video_Id': 'N3jPOXHcNds',
#   'Comment_Text': 'Super nice design ❤️❤️',
#   'Comment_Author': '@MithilasMehndiCorner',
#   'Comment_Published': '2022-11-13T12:11:26Z'},
#  {'Comment_Id': 'Ugy1Q12xOZOMcr1IoKd4AaABAg',
#   'Video_Id': 'JTcFZ5Ne3Js',
#   'Comment_Text': 'Nice 🥰',
#   'Comment_Author': '@kavita_mehndi_art',
#   'Comment_Published': '2022-11-08T05:14:25Z'},
#  {'Comment_Id': 'Ugyl2Pa2qiLf4yXd9gN4AaABAg',
#   'Video_Id': 'wQpANpuKRsk',
#   'Comment_Text': '💕',
#   'Comment_Author': '@ruchibisht1741',
#   'Comment_Published': '2022-11-06T08:07:02Z'},
#  {'Comment_Id': 'UgxKSgO1YN3kib-6hPp4AaABAg',
#   'Video_Id': 'dkNI95p8pBE',
#   'Comment_Text': 'Beautiful 🥰',
#   'Comment_Author': '@kavita_mehndi_art',
#   'Comment_Published': '2022-10-28T04:35:27Z'},
#  {'Comment_Id': 'UgwVzTtD95c7dWZkBWF4AaABAg',
#   'Video_Id': 'WPDPIr1RfUs',
#   'Comment_Text': 'Very nice',
#   'Comment_Author': '@uniquemehndiartandfashion2208',
#   'Comment_Published': '2022-10-23T04:35:47Z'},
#  {'Comment_Id': 'UgxcOOh_qvgmUHtvawt4AaABAg',
#   'Video_Id': '64PeDK3SAWw',
#   'Comment_Text': 'I&#39;m first comment',
#   'Comment_Author': '@tamilarasi6041',
#   'Comment_Published': '2022-10-13T09:08:11Z'},
#  {'Comment_Id': 'UgxwxVlJRtT4xKOmjpx4AaABAg',
#   'Video_Id': 'C5WrTYmFHCc',
#   'Comment_Text': 'First like first view first comment',
#   'Comment_Author': '@mcmehndiart',
#   'Comment_Published': '2022-10-13T04:31:20Z'},
#  {'Comment_Id': 'Ugz-qfEtLHYWuMCyxUh4AaABAg',
#   'Video_Id': 'r5ko2HLnhTI',
#   'Comment_Text': 'Nice design 🥰',
#   'Comment_Author': '@kavita_mehndi_art',
#   'Comment_Published': '2022-10-11T04:42:04Z'},
#  {'Comment_Id': 'UgwGEFLNSTWL6Yi-E8Z4AaABAg',
#   'Video_Id': 'gK7maJranLg',
#   'Comment_Text': 'Beautiful',
#   'Comment_Author': '@rahulsingla744',
#   'Comment_Published': '2022-10-09T05:00:10Z'},
#  {'Comment_Id': 'UgxSKiHjmIRsa0XKeOd4AaABAg',
#   'Video_Id': 'mydHt4PqEXI',
#   'Comment_Text': 'Wow',
#   'Comment_Author': '@letshavemehndifunwithme5471',
#   'Comment_Published': '2022-10-07T05:04:16Z'},
#  {'Comment_Id': 'UgxQdY626xBaaNx_TAJ4AaABAg',
#   'Video_Id': 'c5p1Tdd02sM',
#   'Comment_Text': 'So beautiful❤️❤️❤️',
#   'Comment_Author': '@solemansk9553',
#   'Comment_Published': '2022-10-03T04:41:26Z'},
#  {'Comment_Id': 'Ugxh0oqDm-ZuIREHImp4AaABAg',
#   'Video_Id': 'HHJzX0UerCY',
#   'Comment_Text': 'Nice<br>Pls pin mee<br>Pls pls',
#   'Comment_Author': '@letshavemehndifunwithme5471',
#   'Comment_Published': '2022-09-30T04:46:02Z'},
#  {'Comment_Id': 'UgzQuRWltk6suMHoJIF4AaABAg',
#   'Video_Id': 't5uRHi1GcVA',
#   'Comment_Text': 'Wow',
#   'Comment_Author': '@nightstaraishu05',
#   'Comment_Published': '2022-09-28T04:31:31Z'},
#  {'Comment_Id': 'UgyWMGnEk1EpCwEzbSJ4AaABAg',
#   'Video_Id': 'qdbX1NVPziM',
#   'Comment_Text': 'Very beautiful Design ❤️❤️',
#   'Comment_Author': '@Xyznewmehndi',
#   'Comment_Published': '2022-09-26T04:30:57Z'},
#  {'Comment_Id': 'UgxazS32KNMXoEXtV1h4AaABAg',
#   'Video_Id': '9bvGi3g5mug',
#   'Comment_Text': 'Superb',
#   'Comment_Author': '@VijayKumar-hq2rd',
#   'Comment_Published': '2022-09-24T04:41:04Z'},
#  {'Comment_Id': 'Ugxa8wJ7K1dJ-9biOv54AaABAg',
#   'Video_Id': 'lE8Q78m5qJA',
#   'Comment_Text': 'Beautiful design',
#   'Comment_Author': '@mcmehndiart',
#   'Comment_Published': '2022-09-22T04:35:23Z'},
#  {'Comment_Id': 'Ugx6sDdy0cH3Qhvlfnh4AaABAg',
#   'Video_Id': 'GXYTZsDseMs',
#   'Comment_Text': 'Very Easy and simple for beginners thank you so much for this video please upload more videos like this😃',
#   'Comment_Author': '@roopmehndiarts9822',
#   'Comment_Published': '2022-09-21T05:21:12Z'},
#  {'Comment_Id': 'UgyDAQFb1eGK7HFOTat4AaABAg',
#   'Video_Id': 'eEAwqmpe6FY',
#   'Comment_Text': 'Big nice dear 💕 friend very nice mehndi design😍',
#   'Comment_Author': '@ArtistNikita',
#   'Comment_Published': '2022-09-20T05:36:04Z'},
#  {'Comment_Id': 'UgyyCN7uZsUG9qtmIdR4AaABAg',
#   'Video_Id': 'NHv3VSga85k',
#   'Comment_Text': 'Beautiful 😍',
#   'Comment_Author': '@shoonyhenna',
#   'Comment_Published': '2022-09-19T04:46:27Z'},
#  {'Comment_Id': 'UgzbcFCz-7YkF77xg_B4AaABAg',
#   'Video_Id': '8FIFIv_r8-Y',
#   'Comment_Text': 'Mast',
#   'Comment_Author': '@AaradhyaCraft-or3mg',
#   'Comment_Published': '2022-09-18T05:11:17Z'},
#  {'Comment_Id': 'UgyiTGdVRmhBNKcKua54AaABAg',
#   'Video_Id': 'HhuXRoPaw8M',
#   'Comment_Text': 'Very nice 👌 👍 👏 beautiful 😍 ❤❤',
#   'Comment_Author': '@RIYASHARMA-jg5yf',
#   'Comment_Published': '2022-09-17T04:30:44Z'},
#  {'Comment_Id': 'UgzvU6bnZT1TH9cIJft4AaABAg',
#   'Video_Id': 'KFQHfmsPVlc',
#   'Comment_Text': 'Beautiful design 😍',
#   'Comment_Author': '@chandnialldesigns4924',
#   'Comment_Published': '2022-09-16T05:35:10Z'},
#  {'Comment_Id': 'UgzgE2yQB_qYQWqwsSB4AaABAg',
#   'Video_Id': 'XDq5y_NkLg0',
#   'Comment_Text': 'First',
#   'Comment_Author': '@shoonyhenna',
#   'Comment_Published': '2022-09-15T04:32:23Z'},
#  {'Comment_Id': 'Ugy7OgFstFm3JVtMLFp4AaABAg',
#   'Video_Id': 'Gu54ruPOFdY',
#   'Comment_Text': 'Very nice 👌 👍 👏  ☺',
#   'Comment_Author': '@RIYASHARMA-jg5yf',
#   'Comment_Published': '2022-09-14T04:33:28Z'},
#  {'Comment_Id': 'UgwKLyiw7nzWcelYbvR4AaABAg',
#   'Video_Id': 'diTLW6KMDB0',
#   'Comment_Text': 'Amazing design 😍',
#   'Comment_Author': '@kavita_mehndi_art',
#   'Comment_Published': '2022-09-13T06:52:10Z'},
#  {'Comment_Id': 'UgxtWHQ6zDCOrEeuL0R4AaABAg',
#   'Video_Id': 'TnumdzVdTz4',
#   'Comment_Text': 'Beautiful design...❤❤❤❤',
#   'Comment_Author': '@gruhalakshmiartandcraft6102',
#   'Comment_Published': '2022-09-12T04:33:59Z'},
#  {'Comment_Id': 'UgycUO0Z5EsgouS3FRp4AaABAg',
#   'Video_Id': 'b3WDghJ0qYk',
#   'Comment_Text': 'very nice mehndi sis',
#   'Comment_Author': '@sumitrajangid3298',
#   'Comment_Published': '2022-09-11T13:50:30Z'},
#  {'Comment_Id': 'UgxtAXKS9WYU7mpaTiJ4AaABAg',
#   'Video_Id': 'hSZil5SiYtc',
#   'Comment_Text': '1comment very nice Desgin 👌stay connected',
#   'Comment_Author': '@rangoliartbyrc5283',
#   'Comment_Published': '2022-09-10T04:48:34Z'},
#  {'Comment_Id': 'UgwMwQq39N23pk27qbp4AaABAg',
#   'Video_Id': '43YhKg5HJD8',
#   'Comment_Text': '😍😍',
#   'Comment_Author': '@RIYASHARMA-jg5yf',
#   'Comment_Published': '2022-09-09T08:57:33Z'},
#  {'Comment_Id': 'UgyIc5PbyRNuprLcmLV4AaABAg',
#   'Video_Id': 'pZ4uiGJfjUg',
#   'Comment_Text': 'Beautiful design 👌👌',
#   'Comment_Author': '@afreensmehndiart',
#   'Comment_Published': '2022-09-07T04:32:12Z'},
#  {'Comment_Id': 'UgytnOSAAHZLO7f8ZFZ4AaABAg',
#   'Video_Id': 'BaJAjTLsc2I',
#   'Comment_Text': 'wow its beautiful ❣️❣️❣️❤️❤️💕💞💞🥰😍😍😍<br>  Thanku  so much for this video 🙏❣️😍',
#   'Comment_Author': '@sukeshnidethe7899',
#   'Comment_Published': '2022-09-04T05:38:50Z'},
#  {'Comment_Id': 'Ugwjz9SRPZlVuGUQo2l4AaABAg',
#   'Video_Id': 'R3oyyBO-3rE',
#   'Comment_Text': 'First',
#   'Comment_Author': '@shoonyhenna',
#   'Comment_Published': '2022-09-02T04:32:21Z'},
#  {'Comment_Id': 'UgwSAUX82vLIGyhuTi14AaABAg',
#   'Video_Id': 'NIFFewQs9R0',
#   'Comment_Text': 'Bahut sunder,Happy Teej',
#   'Comment_Author': '@arghya6082',
#   'Comment_Published': '2022-08-30T04:34:58Z'},
#  {'Comment_Id': 'UgwHC3ho_22j74MRqFF4AaABAg',
#   'Video_Id': '_nBgLisbnfU',
#   'Comment_Text': '❤❤',
#   'Comment_Author': '@RiyaRajSinha',
#   'Comment_Published': '2022-08-26T04:31:50Z'},
#  {'Comment_Id': 'Ugx6_HcElgoxMs3D52F4AaABAg',
#   'Video_Id': 'omaMzyawKWg',
#   'Comment_Text': 'Mam , any mehendi classes from you?',
#   'Comment_Author': '@vinitachetwani6584',
#   'Comment_Published': '2022-08-25T04:32:59Z'},
#  {'Comment_Id': 'UgxA_X6n6VDqXqsT2CJ4AaABAg',
#   'Video_Id': '39QMzRDJupY',
#   'Comment_Text': 'So amazing design dear',
#   'Comment_Author': '@mehandidesignerbandana5625',
#   'Comment_Published': '2022-08-24T04:50:44Z'},
#  {'Comment_Id': 'Ugxs8x-P9uLKI83-51l4AaABAg',
#   'Video_Id': 'BCUcx3TPV0g',
#   'Comment_Text': 'First comment nice😎',
#   'Comment_Author': '@rahulsingla744',
#   'Comment_Published': '2022-08-22T04:35:06Z'},
#  {'Comment_Id': 'UgzQR77_V6GOLjcnLhZ4AaABAg',
#   'Video_Id': 'M7CENW_yYBs',
#   'Comment_Text': 'Amazing di best design<br><br>1st comment and like',
#   'Comment_Author': '@artwithayushi6796',
#   'Comment_Published': '2022-08-21T05:02:27Z'},
#  {'Comment_Id': 'UgxhfrqOT9Mkn7yo8zx4AaABAg',
#   'Video_Id': 'vkVjX5UpJQ8',
#   'Comment_Text': 'First to comment',
#   'Comment_Author': '@farooqahmed7275',
#   'Comment_Published': '2022-08-20T04:31:58Z'},
#  {'Comment_Id': 'Ugyb6ohAWnwZQ6CQzGt4AaABAg',
#   'Video_Id': '2VoVCHCHJy8',
#   'Comment_Text': 'Beautiful design sis aap editing nam nhi btae',
#   'Comment_Author': '@amzadkhan9765',
#   'Comment_Published': '2022-08-19T07:36:16Z'},
#  {'Comment_Id': 'UgxSJFs1StnLDx3p5Gx4AaABAg',
#   'Video_Id': '66wLFTV9P20',
#   'Comment_Text': 'Beautiful',
#   'Comment_Author': '@ankitatripathi3559',
#   'Comment_Published': '2022-08-18T04:31:50Z'},
#  {'Comment_Id': 'UgyFN7dnjuXwUAh1X7V4AaABAg',
#   'Video_Id': 'ppk0RRk4Yok',
#   'Comment_Text': 'Nice design',
#   'Comment_Author': '@mcmehndiart',
#   'Comment_Published': '2022-08-17T04:32:27Z'},
#  {'Comment_Id': 'UgwaWp2rLNQk_fV49MZ4AaABAg',
#   'Video_Id': '64u31pPzkqI',
#   'Comment_Text': 'Very beautiful and elegant mehndi design',
#   'Comment_Author': '@SuhuSimpa',
#   'Comment_Published': '2022-08-16T04:31:03Z'},
#  {'Comment_Id': 'UgzpGfLLZg7gm3J1tTt4AaABAg',
#   'Video_Id': '0OZfI2Pm9TE',
#   'Comment_Text': 'Beautiful😍',
#   'Comment_Author': '@secretgirl9698',
#   'Comment_Published': '2022-08-15T04:33:38Z'},
#  {'Comment_Id': 'UgykbLgr2HTnbXZLzQl4AaABAg',
#   'Video_Id': 'UjJHh9jlf4E',
#   'Comment_Text': 'Beautiful 😍',
#   'Comment_Author': '@pariandpranjalkilifestyle5530',
#   'Comment_Published': '2022-08-14T04:46:55Z'},
#  {'Comment_Id': 'Ugxnt0mdTQxZfyKFIo54AaABAg',
#   'Video_Id': 'UmL0uw-rD-Y',
#   'Comment_Text': 'Di please full hand mehndi dulhan mehndi dikhaiye please',
#   'Comment_Author': '@artwork7041',
#   'Comment_Published': '2022-08-13T04:30:41Z'},
#  {'Comment_Id': 'UgwJos40C8GgXDUPFlB4AaABAg',
#   'Video_Id': 'i1d7qG5Y6cc',
#   'Comment_Text': 'So beautiful',
#   'Comment_Author': '@mehndidesign3844',
#   'Comment_Published': '2022-08-12T06:14:15Z'},
#  {'Comment_Id': 'UgzbBWtne8LIr1WuIll4AaABAg',
#   'Video_Id': 'DlVo0C6Dm-M',
#   'Comment_Text': 'Wow sooo sooo beautiful and pretty mehndi design awesome sharing',
#   'Comment_Author': '@mehreenshennaart',
#   'Comment_Published': '2022-08-11T06:36:41Z'},
#  {'Comment_Id': 'UgwinYdHpV-iBkxxOol4AaABAg',
#   'Video_Id': 'E4A75_3pJJk',
#   'Comment_Text': 'Nice design 🥰',
#   'Comment_Author': '@kavita_mehndi_art',
#   'Comment_Published': '2022-08-10T04:42:47Z'},
#  {'Comment_Id': 'UgzeWoSI2qOiZCdy_0t4AaABAg',
#   'Video_Id': 'pw9sAj5XDUw',
#   'Comment_Text': 'Beautiful 😍😍',
#   'Comment_Author': '@artbyrs',
#   'Comment_Published': '2022-08-09T06:58:16Z'},
#  {'Comment_Id': 'UgzE87r9w0R4ZXyf3hp4AaABAg',
#   'Video_Id': 'a6pDLjGEhv8',
#   'Comment_Text': 'Nice design dear 🥰',
#   'Comment_Author': '@kavita_mehndi_art',
#   'Comment_Published': '2022-08-08T05:18:26Z'},
#  {'Comment_Id': 'UgzYXWSz7TuYh3K2GO14AaABAg',
#   'Video_Id': '2yH7dYVcpGY',
#   'Comment_Text': 'Amazing design',
#   'Comment_Author': '@divyanshimehndidesign5806',
#   'Comment_Published': '2022-08-07T04:30:54Z'},
#  {'Comment_Id': 'UgxRVCb9ulELQiBRCUt4AaABAg',
#   'Video_Id': 'd25MDrKx91A',
#   'Comment_Text': 'Nice design💞',
#   'Comment_Author': '@asmehandi',
#   'Comment_Published': '2022-08-06T04:33:39Z'},
#  {'Comment_Id': 'UgwaZsMVF6_ZUMwqRsp4AaABAg',
#   'Video_Id': 'coAykhr-CtY',
#   'Comment_Text': 'Beautiful😍💓',
#   'Comment_Author': '@asmehandi',
#   'Comment_Published': '2022-08-05T04:32:41Z'},
#  {'Comment_Id': 'UgwCxKYpBPuNSNouOiN4AaABAg',
#   'Video_Id': 'gBuwt49J7M8',
#   'Comment_Text': 'Awesomely designe must try this on rakhi',
#   'Comment_Author': '@ritukashyap2680',
#   'Comment_Published': '2022-08-04T04:53:43Z'},
#  {'Comment_Id': 'UgxZSsYGRYFEQiTAXOd4AaABAg',
#   'Video_Id': 'vDrOm_KxPJE',
#   'Comment_Text': 'Amazing design 💕😍',
#   'Comment_Author': '@asmehandi',
#   'Comment_Published': '2022-08-03T04:57:01Z'},
#  {'Comment_Id': 'UgwgGLm9UqclEz8ypGl4AaABAg',
#   'Video_Id': 'y96t_7GaXvk',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=cqjqWG2wgXQ">https://youtu.be/cqjqWG2wgXQ</a> Please watch my Vedio',
#   'Comment_Author': '@asmehandi',
#   'Comment_Published': '2022-08-02T04:32:28Z'},
#  {'Comment_Id': 'Ugycyk8liVRprxcjABV4AaABAg',
#   'Video_Id': 'ekItfiNmy4g',
#   'Comment_Text': 'Nice 😊😊😊😊 I m first viewer',
#   'Comment_Author': '@noorfatima2155',
#   'Comment_Published': '2022-08-01T04:34:28Z'},
#  {'Comment_Id': 'Ugxor3PuFBPPd59mVz54AaABAg',
#   'Video_Id': '6rVqgmdNCIo',
#   'Comment_Text': 'First comment 💗❤',
#   'Comment_Author': '@rahulsingla744',
#   'Comment_Published': '2022-07-31T04:32:35Z'},
#  {'Comment_Id': 'UgwNKoHHmELZQMad11p4AaABAg',
#   'Video_Id': 'w43AxRhQaGc',
#   'Comment_Text': 'Wowv yal so beautiful😊',
#   'Comment_Author': '@imranlahori3095',
#   'Comment_Published': '2022-07-30T14:33:18Z'},
#  {'Comment_Id': 'UgztxzSnqzZp26CcpPd4AaABAg',
#   'Video_Id': 'e1OVr3rW5hg',
#   'Comment_Text': 'Hii',
#   'Comment_Author': '@pinkimehendiart1917',
#   'Comment_Published': '2022-07-30T04:38:03Z'},
#  {'Comment_Id': 'UgwhTR46cvZyXyYym-54AaABAg',
#   'Video_Id': 'mYWXFlU_-_M',
#   'Comment_Text': 'Nice design',
#   'Comment_Author': '@divyanshimehndidesign5806',
#   'Comment_Published': '2022-07-29T04:50:38Z'},
#  {'Comment_Id': 'UgzDRi5NsUsSS5xCxSx4AaABAg',
#   'Video_Id': 'QGXmqcsELDE',
#   'Comment_Text': 'Nice dii',
#   'Comment_Author': '@SatpalSingh-cn2zw',
#   'Comment_Published': '2022-07-28T04:31:09Z'},
#  {'Comment_Id': 'UgyTuz9pA87mhjdfu-x4AaABAg',
#   'Video_Id': 'nwqFUeUgVQU',
#   'Comment_Text': 'Nice ; Beautiful',
#   'Comment_Author': '@divyanshimehndidesign5806',
#   'Comment_Published': '2022-07-27T04:32:36Z'},
#  {'Comment_Id': 'Ugx58VkTen_uXJWUICF4AaABAg',
#   'Video_Id': 'qgsI6998ACw',
#   'Comment_Text': 'Wow,Amazing',
#   'Comment_Author': '@divyanshimehndidesign5806',
#   'Comment_Published': '2022-07-26T04:32:26Z'},
#  {'Comment_Id': 'UgxWyemN2wUUeBTEl8x4AaABAg',
#   'Video_Id': 'gFqGcTbs33Q',
#   'Comment_Text': '🥰🥰👌👌',
#   'Comment_Author': '@MEHNDIPLANT',
#   'Comment_Published': '2022-07-25T04:53:42Z'},
#  {'Comment_Id': 'Ugzxs4K9MzPnjvRJFC54AaABAg',
#   'Video_Id': 'W7wGfpeBKic',
#   'Comment_Text': 'First like...🤘',
#   'Comment_Author': '@ankitachavan4182',
#   'Comment_Published': '2022-07-24T04:33:05Z'},
#  {'Comment_Id': 'UgxlV07LoXvdBnGsKcJ4AaABAg',
#   'Video_Id': 'p488zMYBQNQ',
#   'Comment_Text': 'First view 🥰 nice design',
#   'Comment_Author': '@kavita_mehndi_art',
#   'Comment_Published': '2022-07-23T04:31:06Z'},
#  {'Comment_Id': 'UgzPs4kdfHJjC8DdLWV4AaABAg',
#   'Video_Id': 'lXStnrZh9tE',
#   'Comment_Text': 'Nice',
#   'Comment_Author': '@divyanshimehndidesign5806',
#   'Comment_Published': '2022-07-22T04:39:31Z'},
#  {'Comment_Id': 'Ugy3fHTosCQoU67fFVl4AaABAg',
#   'Video_Id': 'qPJMWoY-BWk',
#   'Comment_Text': 'nice🤗🥰🥰🥰👌',
#   'Comment_Author': '@MEHNDIPLANT',
#   'Comment_Published': '2022-07-21T05:10:10Z'},
#  {'Comment_Id': 'UgyNImS_vJne_ImcaCt4AaABAg',
#   'Video_Id': 'TkQoxCADfc8',
#   'Comment_Text': 'New Subscribers: kAVYA PAL MEHNDI',
#   'Comment_Author': '@kavyamehndi',
#   'Comment_Published': '2022-07-20T04:42:38Z'},
#  {'Comment_Id': 'UgxQKH5nHgzSPgUwBw54AaABAg',
#   'Video_Id': 'OBV7ko0NS_c',
#   'Comment_Text': 'Wow nice',
#   'Comment_Author': '@ammehndidesign1954',
#   'Comment_Published': '2022-07-19T04:31:30Z'},
#  {'Comment_Id': 'UgzjySH_FqwKrJpuhJB4AaABAg',
#   'Video_Id': 'r4GzXFV57lA',
#   'Comment_Text': 'nice👌👌 beautifull 😍',
#   'Comment_Author': '@MEHNDIPLANT',
#   'Comment_Published': '2022-07-18T05:05:27Z'},
#  {'Comment_Id': 'UgzokeIawcBOr0Z7KNd4AaABAg',
#   'Video_Id': '6JXpZTnKkI4',
#   'Comment_Text': 'Nice ; Beautiful',
#   'Comment_Author': '@divyanshimehndidesign5806',
#   'Comment_Published': '2022-07-17T04:31:53Z'},
#  {'Comment_Id': 'Ugw8qcjyJ_IcHJ32JTZ4AaABAg',
#   'Video_Id': 'Uwq8SvkG-gU',
#   'Comment_Text': 'Beautiful',
#   'Comment_Author': '@divyanshimehndidesign5806',
#   'Comment_Published': '2022-07-16T04:34:23Z'},
#  {'Comment_Id': 'UgzYdzIp0YOFKKj7EBR4AaABAg',
#   'Video_Id': 'TeWHf1mtThk',
#   'Comment_Text': 'Wow Amazing',
#   'Comment_Author': '@divyanshimehndidesign5806',
#   'Comment_Published': '2022-07-15T04:33:43Z'},
#  {'Comment_Id': 'UgxB_3w1pBADxGlcuTl4AaABAg',
#   'Video_Id': 'vTz2fg0JPGM',
#   'Comment_Text': 'Very beautiful design 🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️',
#   'Comment_Author': '@kavyamehndi',
#   'Comment_Published': '2022-07-14T04:31:09Z'},
#  {'Comment_Id': 'UgwxPAciizPsCYB9PCd4AaABAg',
#   'Video_Id': '6jRWHc5tSCE',
#   'Comment_Text': 'Beautiful',
#   'Comment_Author': '@rosemehndiclasses',
#   'Comment_Published': '2022-07-13T11:33:19Z'},
#  {'Comment_Id': 'UgymzL-J3mgHOanmsyJ4AaABAg',
#   'Video_Id': 'b5Z2QIq0PmI',
#   'Comment_Text': '👌👌👌🥰 beautifull',
#   'Comment_Author': '@MEHNDIPLANT',
#   'Comment_Published': '2022-07-13T04:33:39Z'},
#  {'Comment_Id': 'Ugy-YDmFEF35fMa5IQh4AaABAg',
#   'Video_Id': 'SHRMNeHwNYM',
#   'Comment_Text': 'First time com beautiful Mehndi',
#   'Comment_Author': '@AishaPaperCrafts',
#   'Comment_Published': '2022-07-12T04:44:19Z'},
#  {'Comment_Id': 'Ugw4TDr_RefDnvnJhWl4AaABAg',
#   'Video_Id': 'vPV7k5iDHS8',
#   'Comment_Text': 'It is so beautiful mehndi design 👍',
#   'Comment_Author': '@ArtistNikita',
#   'Comment_Published': '2022-07-11T04:51:35Z'},
#  {'Comment_Id': 'Ugyy0lkI9RIQOHaJ4bp4AaABAg',
#   'Video_Id': 'VqNzFvdWdKY',
#   'Comment_Text': 'Gajabb degein',
#   'Comment_Author': '@asmehandi',
#   'Comment_Published': '2022-07-10T04:50:44Z'},
#  {'Comment_Id': 'Ugzl0bLNJoumTVfBNxN4AaABAg',
#   'Video_Id': 'wv3JlGlDBjo',
#   'Comment_Text': 'First like👍<br>Beautiful design',
#   'Comment_Author': '@rahinimehndicreation5169',
#   'Comment_Published': '2022-07-09T04:36:44Z'},
#  {'Comment_Id': 'UgwO7cSlkOc2yCvSt8x4AaABAg',
#   'Video_Id': 'DSUanbn3Mgg',
#   'Comment_Text': 'Osmm',
#   'Comment_Author': '@lonesanaya4526',
#   'Comment_Published': '2022-07-08T04:32:04Z'},
#  {'Comment_Id': 'Ugx_3WHZXdJnuPnQzB14AaABAg',
#   'Video_Id': 'Uee0CYrcn9A',
#   'Comment_Text': 'Beautiful mehndi designs mam',
#   'Comment_Author': '@MehandidesignbyRutuja',
#   'Comment_Published': '2022-07-07T04:30:28Z'},
#  {'Comment_Id': 'UgxmAJN4f3GVeNef_MR4AaABAg',
#   'Video_Id': '2-agDa1fb3w',
#   'Comment_Text': '👌👌😊',
#   'Comment_Author': '@MEHNDIPLANT',
#   'Comment_Published': '2022-07-06T04:37:56Z'},
#  {'Comment_Id': 'UgwAqTVEKxDEFA0bStR4AaABAg',
#   'Video_Id': 'rhukLSlZVl8',
#   'Comment_Text': '😲😳😳',
#   'Comment_Author': '@MirRisalat-56',
#   'Comment_Published': '2022-07-05T04:32:45Z'},
#  {'Comment_Id': 'UgwLaxupvg85XiQiCgl4AaABAg',
#   'Video_Id': 'jlClBoi9P8E',
#   'Comment_Text': 'Good',
#   'Comment_Author': '@AishaPaperCrafts',
#   'Comment_Published': '2022-07-04T04:41:10Z'},
#  {'Comment_Id': 'UgxXKmvVRyCyl6GyTj54AaABAg',
#   'Video_Id': 'YOTMMR8yF0E',
#   'Comment_Text': '🥰🥰',
#   'Comment_Author': '@remutv696',
#   'Comment_Published': '2022-07-03T04:47:56Z'},
#  {'Comment_Id': 'UgwbzBuW2ztt0RGDLmF4AaABAg',
#   'Video_Id': 'YQoEnSOiH8s',
#   'Comment_Text': 'First like👍<br>Beautiful design',
#   'Comment_Author': '@rahinimehndicreation5169',
#   'Comment_Published': '2022-07-02T04:31:26Z'},
#  {'Comment_Id': 'UgwAdnk6dHl7QRCkrv54AaABAg',
#   'Video_Id': '8hcRZHqSniE',
#   'Comment_Text': 'Nice dii. <br>1st view',
#   'Comment_Author': '@Mannat_Sharma',
#   'Comment_Published': '2022-07-01T04:32:19Z'},
#  {'Comment_Id': 'UgyJCxvxtJkbNHMB29d4AaABAg',
#   'Video_Id': '3tolI3GsbW4',
#   'Comment_Text': '1st comment appi ❤️ beautiful mehendi design 🥀🥀🥀',
#   'Comment_Author': '@_VN_views',
#   'Comment_Published': '2022-06-28T04:34:15Z'},
#  {'Comment_Id': 'Ugw4R2YDuNmQBf0CxSN4AaABAg',
#   'Video_Id': 'ixqXOheiyOU',
#   'Comment_Text': 'Awsm 😍😍',
#   'Comment_Author': '@rahulsingla744',
#   'Comment_Published': '2022-06-26T04:44:41Z'},
#  {'Comment_Id': 'UgyLU2kS_Mq9orosS3B4AaABAg',
#   'Video_Id': 'zlIOEgxUgnU',
#   'Comment_Text': 'Wow.. nice... 🥰🥰',
#   'Comment_Author': '@hennahome8652',
#   'Comment_Published': '2022-06-24T04:35:15Z'},
#  {'Comment_Id': 'UgzKIWZ5dYTEvrI-T2J4AaABAg',
#   'Video_Id': '0s0B-IAO4F0',
#   'Comment_Text': 'Oowww you are great❣️❣️😍',
#   'Comment_Author': '@jannat5556',
#   'Comment_Published': '2022-06-22T04:35:18Z'},
#  {'Comment_Id': 'Ugx6oHSGmezjpDv5gpp4AaABAg',
#   'Video_Id': 'onG-vlqwcWA',
#   'Comment_Text': 'Nice❤️',
#   'Comment_Author': '@MuskanMehndiArt',
#   'Comment_Published': '2022-06-20T04:31:21Z'},
#  {'Comment_Id': 'Ugxuz7pNljBmBQFEmsV4AaABAg',
#   'Video_Id': 'vDQkakMhEGM',
#   'Comment_Text': 'Beautiful design',
#   'Comment_Author': '@rahinimehndicreation5169',
#   'Comment_Published': '2022-06-18T05:23:38Z'},
#  {'Comment_Id': 'Ugy39KY3drPKMrXV5Ax4AaABAg',
#   'Video_Id': '78P9DZBNpSg',
#   'Comment_Text': 'fast comment 💚💚💚',
#   'Comment_Author': '@mdjwelislamic9450',
#   'Comment_Published': '2022-06-16T04:33:13Z'},
#  {'Comment_Id': 'Ugzns36dDNPyJyNd-k14AaABAg',
#   'Video_Id': 'k1BB4c3fn1Y',
#   'Comment_Text': 'Nice',
#   'Comment_Author': '@manishsonkar1812',
#   'Comment_Published': '2022-06-14T04:34:57Z'},
#  {'Comment_Id': 'Ugy9d1Xb2vepBZJ_He94AaABAg',
#   'Video_Id': 'BB3eIaj0MC8',
#   'Comment_Text': 'first viewer',
#   'Comment_Author': '@MUSAL-MAN72',
#   'Comment_Published': '2022-06-11T04:31:10Z'},
#  {'Comment_Id': 'UgwktZ6Pg7_NK9Lw-3R4AaABAg',
#   'Video_Id': 'qquQSdWoLwY',
#   'Comment_Text': 'Beautiful mehndi design.. please subscribe to my channel',
#   'Comment_Author': '@MehandidesignbyRutuja',
#   'Comment_Published': '2022-06-09T04:39:21Z'},
#  {'Comment_Id': 'Ugz1RRKet9o_0_dzr9x4AaABAg',
#   'Video_Id': 'uiirJkQVRyc',
#   'Comment_Text': 'First like👍<br>Very beautiful design',
#   'Comment_Author': '@rahinimehndicreation5169',
#   'Comment_Published': '2022-06-07T04:31:57Z'},
#  {'Comment_Id': 'Ugxf8x-2SMKi3kS488t4AaABAg',
#   'Video_Id': 'coP88QlVd6g',
#   'Comment_Text': 'Nice',
#   'Comment_Author': '@20Second-Shorts',
#   'Comment_Published': '2022-06-04T04:37:54Z'},
#  {'Comment_Id': 'UgwiXC-uoqcJ7Mb2NKd4AaABAg',
#   'Video_Id': '7bUFHx9U0Fs',
#   'Comment_Text': 'Beautiful mehndi design 🥰',
#   'Comment_Author': '@kavita_mehndi_art',
#   'Comment_Published': '2022-05-31T04:37:05Z'},
#  {'Comment_Id': 'Ugz6ydstnY0-R5PL2K14AaABAg',
#   'Video_Id': 'fFbE9Mxjxp0',
#   'Comment_Text': 'Beautiful 🥰',
#   'Comment_Author': '@shoonyhenna',
#   'Comment_Published': '2022-05-27T04:32:49Z'},
#  {'Comment_Id': 'UgyjFJnt5z32nZ2w3e94AaABAg',
#   'Video_Id': '-mlqSym8Ags',
#   'Comment_Text': 'I am first',
#   'Comment_Author': '@dancewithvandana8602',
#   'Comment_Published': '2022-05-25T04:38:06Z'},
#  {'Comment_Id': 'UgyDnlfKIif-l5F4ewl4AaABAg',
#   'Video_Id': 'PpohBbzsH2g',
#   'Comment_Text': 'Very beautiful design dear friend 😊<br>Please pin my comment 🤪',
#   'Comment_Author': '@cutiemehendiart',
#   'Comment_Published': '2022-05-21T04:33:14Z'},
#  {'Comment_Id': 'UgyNKmAllJOZsvRSTTZ4AaABAg',
#   'Video_Id': 'DS2Pmbw2cMg',
#   'Comment_Text': '👌👌👌👌👌',
#   'Comment_Author': '@swapnagare1864',
#   'Comment_Published': '2022-05-16T04:38:55Z'},
#  {'Comment_Id': 'UgxXjQhz8lFcxi4R3oR4AaABAg',
#   'Video_Id': 'ziq-rufeHVs',
#   'Comment_Text': 'Super',
#   'Comment_Author': '@AbdulGani-nb9yp',
#   'Comment_Published': '2022-05-14T04:32:55Z'},
#  {'Comment_Id': 'UgwB7-NEbFemipPeVaF4AaABAg',
#   'Video_Id': '0KEuTtcBmBU',
#   'Comment_Text': 'Super di 💖',
#   'Comment_Author': '@shivaniarts4551',
#   'Comment_Published': '2022-05-12T04:36:10Z'},
#  {'Comment_Id': 'UgxhP85AbouUkAGSd6N4AaABAg',
#   'Video_Id': 'qDP5GGfGHi8',
#   'Comment_Text': 'Wonderful',
#   'Comment_Author': '@komalkmalhotra3271',
#   'Comment_Published': '2022-05-10T04:31:26Z'},
#  {'Comment_Id': 'UgxXPAaFg57NciO5iL54AaABAg',
#   'Video_Id': 'Dy-D7C8K9K0',
#   'Comment_Text': 'Wow so beautiful mehndi diiii ❤️🌼',
#   'Comment_Author': '@toshibaagrawal5551',
#   'Comment_Published': '2022-05-08T04:33:29Z'},
#  {'Comment_Id': 'UgzLuYFuzjAtDYnoB3Z4AaABAg',
#   'Video_Id': 'DBdvMUOFyI4',
#   'Comment_Text': 'Amazing design and quality of video 😍',
#   'Comment_Author': '@kavita_mehndi_art',
#   'Comment_Published': '2022-05-06T05:29:12Z'},
#  {'Comment_Id': 'UgxT8ujo5cdfO_2dMKl4AaABAg',
#   'Video_Id': 'RYTgfaFGtVM',
#   'Comment_Text': '<b>Nice design</b>',
#   'Comment_Author': '@Neelu88',
#   'Comment_Published': '2022-04-29T04:33:21Z'},
#  {'Comment_Id': 'UgzurGPhqlNPS_EG6bN4AaABAg',
#   'Video_Id': 'IoHhe4hwRDA',
#   'Comment_Text': 'Very beautiful',
#   'Comment_Author': '@artbyrs',
#   'Comment_Published': '2022-04-26T04:37:45Z'},
#  {'Comment_Id': 'UgwJFqwI5JtnB2jINPZ4AaABAg',
#   'Video_Id': 'YpEyKSY_vPw',
#   'Comment_Text': 'Beautiful design ❤️',
#   'Comment_Author': '@hennatutorials9562',
#   'Comment_Published': '2022-04-21T04:34:50Z'},
#  {'Comment_Id': 'UgzNxuzpEYMDFqixA8t4AaABAg',
#   'Video_Id': 'l_i2JaP-w90',
#   'Comment_Text': 'How can you make such beautiful designs ❤️',
#   'Comment_Author': '@ritimabhagat2477',
#   'Comment_Published': '2022-04-09T04:38:51Z'},
#  {'Comment_Id': 'UgzKnBo02h9x82nry9V4AaABAg',
#   'Video_Id': 'EJHSHXe5gtM',
#   'Comment_Text': 'Beautiful mehndi design🌹💖💞',
#   'Comment_Author': '@amamehndidesign2333',
#   'Comment_Published': '2022-04-07T15:37:13Z'},
#  {'Comment_Id': 'UgzZJunl82Y2TWv7_Fp4AaABAg',
#   'Video_Id': 'gby-JrRLfJI',
#   'Comment_Text': 'Nice',
#   'Comment_Author': '@kushiajain149',
#   'Comment_Published': '2022-04-05T04:31:33Z'},
#  {'Comment_Id': 'Ugy8qk3REray60ofpGZ4AaABAg',
#   'Video_Id': '9NHRYtejdTI',
#   'Comment_Text': 'Very nice 👍🙂',
#   'Comment_Author': '@KhushiSingh-df5op',
#   'Comment_Published': '2022-04-03T04:44:17Z'},
#  {'Comment_Id': 'UgyopPh78jK-y_foE5Z4AaABAg',
#   'Video_Id': 'gsDrRPsg-Jc',
#   'Comment_Text': 'Superb di 😍🤗',
#   'Comment_Author': '@omrajgadekar2688',
#   'Comment_Published': '2022-04-01T04:41:13Z'},
#  {'Comment_Id': 'UgwVIfDtiKiwihXtf_t4AaABAg',
#   'Video_Id': '7PgOyhV42FY',
#   'Comment_Text': '🥰nice',
#   'Comment_Author': '@priyarampal2695',
#   'Comment_Published': '2022-03-30T04:38:26Z'},
#  {'Comment_Id': 'UgwUS4my1S4HjUO_EV94AaABAg',
#   'Video_Id': 'dXn17i_pUlw',
#   'Comment_Text': 'Most beautiful mehendi didi ji 💫💫💫💫💫✨✨✨✨✨',
#   'Comment_Author': '@_VN_views',
#   'Comment_Published': '2022-03-28T04:35:56Z'},
#  {'Comment_Id': 'UgxCac_7eOQ9nRwaeSN4AaABAg',
#   'Video_Id': 'w4rnxbEoDt4',
#   'Comment_Text': 'Beautiful didi me ek mehendi artist hu 💫✨💫✨',
#   'Comment_Author': '@_VN_views',
#   'Comment_Published': '2022-03-26T05:10:08Z'},
#  {'Comment_Id': 'UgwdeAM7ewvZmSfc1rh4AaABAg',
#   'Video_Id': 'tFlDBSQmqng',
#   'Comment_Text': 'First Viewer',
#   'Comment_Author': '@aakankshadhore106',
#   'Comment_Published': '2022-03-15T04:31:06Z'}]

# %%
#GETTING PLAYLIST INFORMATION
def get_playlist_details(channel_id):
    next_page_token=None
    all_data=[]
    while True:
            request = youtube.playlists().list(
                part="snippet,contentDetails",
                channelId=channel_id,
                maxResults=50,
                pageToken=next_page_token
            )
            response=request.execute()
            for i in response['items']:
                data=dict(Playlist_Id=i['id'],
                          Title=i['snippet']['title'],
                          Channel_Id=i['snippet']['channelId'],
                          Channel_Name=i['snippet']['channelTitle'],
                          PublishedAt=i['snippet']['publishedAt'],
                          Video_Count=i['contentDetails']['itemCount']
                    
                    )
                all_data.append(data)
            next_page_token=response.get('nextPageToken')
            if next_page_token is None:
                   break
    return all_data

# %%
playlist_details=get_playlist_details("UCzjNADgaUyuH8ffMhxmphRw")
playlist_details
# Out:
# [{'Playlist_Id': 'PLDhpFgw6Zbf-dR4TO7MkyUZ7bDGa07LS_',
#   'Title': 'ABC Alphabet, Numbers and Shapes',
#   'Channel_Id': 'UCzjNADgaUyuH8ffMhxmphRw',
#   'Channel_Name': 'Magic Fingers Art',
#   'PublishedAt': '2023-11-10T11:51:00Z',
#   'Video_Count': 25},
#  {'Playlist_Id': 'PLDhpFgw6Zbf-bTuyojYuyYNLy9iDBcZIs',
#   'Title': 'Toddlers',
#   'Channel_Id': 'UCzjNADgaUyuH8ffMhxmphRw',
#   'Channel_Name': 'Magic Fingers Art',
#   'PublishedAt': '2023-11-09T14:07:31Z',
#   'Video_Count': 73},
#  {'Playlist_Id': 'PLDhpFgw6Zbf99J7yWOPesBGqs09z4-sUK',
#   'Title': 'Shorts',
#   'Channel_Id': 'UCzjNADgaUyuH8ffMhxmphRw',
#   'Channel_Name': 'Magic Fingers Art',
#   'PublishedAt': '2023-09-20T12:24:39Z',
#   'Video_Count': 25},
#  {'Playlist_Id': 'PLDhpFgw6Zbf8_TfjNBQSgrYgXyDR12E7a',
#   'Title': 'Wheels',
#   'Channel_Id': 'UCzjNADgaUyuH8ffMhxmphRw',
#   'Channel_Name': 'Magic Fingers Art',
#   'PublishedAt': '2020-11-20T07:47:56Z',
#   'Video_Count': 25},
#  {'Playlist_Id': 'PLDhpFgw6Zbf9cS0FsvT_xIAzqvH1g1IPn',
#   'Title': 'Watercolor',
#   'Channel_Id': 'UCzjNADgaUyuH8ffMhxmphRw',
#   'Channel_Name': 'Magic Fingers Art',
#   'PublishedAt': '2020-08-12T10:56:28Z',
#   'Video_Count': 167},
#  {'Playlist_Id': 'PLDhpFgw6Zbf_xBj-G6N9aL2LdCUovpOr6',
#   'Title': 'Fruits & Vegetables',
#   'Channel_Id': 'UCzjNADgaUyuH8ffMhxmphRw',
#   'Channel_Name': 'Magic Fingers Art',
#   'PublishedAt': '2020-01-25T17:47:35Z',
#   'Video_Count': 25},
#  {'Playlist_Id': 'PLDhpFgw6Zbf-z39EtUOVfKzSnOo5846Oi',
#   'Title': 'Rainbow 🌈',
#   'Channel_Id': 'UCzjNADgaUyuH8ffMhxmphRw',
#   'Channel_Name': 'Magic Fingers Art',
#   'PublishedAt': '2019-12-14T16:27:50Z',
#   'Video_Count': 21},
#  {'Playlist_Id': 'PLDhpFgw6Zbf9kBP6EnfFdHNp7uKdjvEPQ',
#   'Title': 'Sea Animals',
#   'Channel_Id': 'UCzjNADgaUyuH8ffMhxmphRw',
#   'Channel_Name': 'Magic Fingers Art',
#   'PublishedAt': '2019-12-14T16:14:12Z',
#   'Video_Count': 13},
#  {'Playlist_Id': 'PLDhpFgw6Zbf9pQ5w3_pboWDP6ja-2WOBL',
#   'Title': 'Home Sweet Home',
#   'Channel_Id': 'UCzjNADgaUyuH8ffMhxmphRw',
#   'Channel_Name': 'Magic Fingers Art',
#   'PublishedAt': '2019-04-30T18:12:40Z',
#   'Video_Count': 41},
#  {'Playlist_Id': 'PLDhpFgw6Zbf-m0txwKlMX0yMMP_aIEZD8',
#   'Title': 'Animal Friends',
#   'Channel_Id': 'UCzjNADgaUyuH8ffMhxmphRw',
#   'Channel_Name': 'Magic Fingers Art',
#   'PublishedAt': '2019-03-09T15:13:57Z',
#   'Video_Count': 38},
#  {'Playlist_Id': 'PLDhpFgw6Zbf_g-ZSLNJmO9GdMWTl7YG7c',
#   'Title': 'Colors',
#   'Channel_Id': 'UCzjNADgaUyuH8ffMhxmphRw',
#   'Channel_Name': 'Magic Fingers Art',
#   'PublishedAt': '2019-01-12T21:30:19Z',
#   'Video_Count': 191}]

# %%
#CONNECTION OF MONGODB

client=pymongo.MongoClient("mongodb://localhost:27017") # connection to mongo db

# %%
#CREATION OF DATABASE
db=client["youtube_project"] # db creation

# %%
def chennal_detail(channel_id):# function creation
    channel_details=get_channel_info(channel_id)
    playlist_detail=get_playlist_details(channel_id)
    videoid_detail=get_video_ids(channel_id)
    video_detail=get_video_info(videoid_detail)
    comment_detail=get_comment_info(videoid_detail)
    
    #collection creation
    
    collection=db["chennal_details"] # channel_deatils name of the collection
    collection.insert_one({"channel_information":channel_details, # key with values ,values are the function of data collections
                           "video_information":video_detail,
                           "playlist_information":playlist_detail,
                           "comment_information":comment_detail})
    
    
    return "upload completed"

# %%
data_insert=chennal_detail('UCuzuuA9F-UAKf9w5-DUtmBw')

# %%
#UCoM-onrjPOoLtCqIHqGhSag :magish cocktail
#UCKH5MzuD49rbnbBMON2AAIQ
#UCSw_1gwDALwmgoWlXaCFdLg
#UCEtBAdSGzYVnvacVszVLREA
#UCelxoc1vYhrNgODd-LZpDtA
#UCeQnqwVSQM8W0o1E5nWql2g
#UC2CHObJIlxp5hogN775ZP_g
#UCB_9w_j7jqEOqfhKejM7b-g
#UCy1lBBbXhtfzugF_LK2b6Yw
#UCxugP1KCA0dI_hO9vclsobg
# UClAloP4xff1FZHBFXfj9emA
#UCuzuuA9F-UAKf9w5-DUtmBw

# %%
#CHANNEL INFORMATION EXTRACT-TABLE CREATION

def channel_information():
    myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='Navi@1996',database='youtube_project')
    cursor=myconnection.cursor()

    drop_query='''drop table if exists channels'''
    cursor.execute(drop_query)
    myconnection.commit()

    create_query='''create table if not exists channels(Channel_Name varchar(100),
                                                            Channel_Id varchar(100) primary key,
                                                            Subscribers bigint,
                                                            Views bigint,
                                                            Total_Videos int,
                                                            Channel_Description text,
                                                            Playlist_Id varchar(80))'''
    cursor.execute(create_query)
    myconnection.commit()

    ch_list=[]
    db=client["youtube_project"]
    collection=db["chennal_details"]
    for ch_data in collection.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
        
    df=pd.DataFrame(ch_list)

    for index,row in df.iterrows():
            insert_query='''insert into channels(Channel_Name,
                                                Channel_Id,
                                                Subscribers,
                                                Views,
                                                Total_Videos,
                                                Channel_Description,
                                                Playlist_Id)
                                                
                                                values(%s,%s,%s,%s,%s,%s,%s)'''
                                                
            values=(row["Channel_Name"],
                row["Channel_Id"],
                row["Subscribers"],
                row["Views"],
                row["Total_Videos"],
                row["Channel_Description"],
                row["Playlist_Id"])
            
            cursor.execute(insert_query,values)
            myconnection.commit()

# %%
#TABLE CREATION IN SQL
import pymysql
import mysql.connector
import datetime
myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='Navi@1996')
cursor=myconnection.cursor()

# %%
#playlist data extract/table creation

def playlist_information():
    myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='Navi@1996',database='youtube_project')
    cursor=myconnection.cursor()
    
    drop_query='''drop table if exists play_list'''
    cursor.execute(drop_query)
    myconnection.commit()
    create_query='''create table if not exists play_list(Playlist_Id varchar(100) primary key,
                                                            Title varchar(100),
                                                            Channel_Id varchar(100),
                                                            Channel_Name varchar(100),
                                                            PublishedAt DATETIME,
                                                            Video_Count int)'''
                                                            
                                                            
                                                            
    cursor.execute(create_query)
    myconnection.commit()
    #extract data
    pl_list=[]
    db=client["youtube_project"]
    collection=db["chennal_details"]
    for pl_data in collection.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])
        
    df1=pd.DataFrame(pl_list)
    #insering data into sql
    for index,row in df1.iterrows():
            insert_query='''insert into play_list(Playlist_Id,
                                                Title,
                                                Channel_Id,
                                                Channel_Name,
                                                PublishedAt,
                                                Video_Count)
                                                
                                                values(%s,%s,%s,%s,%s,%s)'''
                                                
                                                
            values=(row["Playlist_Id"],
                row["Title"],
                row["Channel_Id"],
                row["Channel_Name"],
                datetime.datetime.strptime(row["PublishedAt"],'%Y-%m-%dT%H:%M:%SZ'),
                row["Video_Count"])
            
            
            
            cursor.execute(insert_query,values)
            myconnection.commit()

# %%
#TABLE CREATION IN SQL
import pymysql
import mysql.connector
import datetime
myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='Navi@1996')
cursor=myconnection.cursor()

# %%
myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='Navi@1996',database='youtube_project')
cursor=myconnection.cursor()

# %%
def comment_information():
    myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='Navi@1996',database='youtube_project')
    cursor=myconnection.cursor()

    drop_query='''drop table if exists comments'''
    cursor.execute(drop_query)
    myconnection.commit()

    create_query='''create table if not exists comments(Comment_Id varchar(200),
                                                        Video_Id varchar(300),
                                                        Comment_Text text,
                                                        Comment_Author varchar(100),
                                                        Comment_Published DATETIME)'''
                                                    
    cursor.execute(create_query)
    myconnection.commit()

    cl_list=[]
    db=client["youtube_project"]
    collection=db["chennal_details"]
    for cl_data in collection.find({},{"_id":0,"comment_information":1}):
        for i in range(len(cl_data["comment_information"])):
           cl_list.append(cl_data["comment_information"][i])
        
    df4=pd.DataFrame(cl_list)

    for index,row in df4.iterrows():
        
        insert_query='''insert into comments(Comment_Id,
                                            Video_Id,
                                            Comment_Text,
                                            Comment_Author,
                                            Comment_Published)
                                            values(%s,%s,%s,%s,%s)'''
        values=(row["Comment_Id"],
            row["Video_Id"],
            row["Comment_Text"],
            row["Comment_Author"],
            datetime.datetime.strptime(row["Comment_Published"],'%Y-%m-%dT%H:%M:%SZ')
            
            )
        cursor.execute(insert_query,values)
        myconnection.commit()

# %%
#videos data extact and inserting
db=client["youtube_project"] # db creation

# %%
import pymysql
import mysql.connector
import datetime

myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='Navi@1996')
cursor=myconnection.cursor()

# %%
def video_information():
  myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='Navi@1996',database='youtube_project')
  cursor=myconnection.cursor()

  drop_query='''drop table if exists video_list'''
  cursor.execute(drop_query)
  myconnection.commit()

  create_query='''create table if not exists video_list(Channel_Name varchar(300),
                                                    Channel_Id varchar(300),
                                                    Video_Id varchar(300) primary key,
                                                    Title varchar(100),
                                                    Thumbnail varchar(250),
                                                    Comments int,
                                                    Like_Count int,
                                                    Dislike_Count int,
                                                    Faviorite int,
                                                    Description text,
                                                    Published_Date DATETIME,
                                                    Duration varchar(100),
                                                    Views int,
                                                    Definition varchar(100),
                                                    Caption_Status varchar(100))'''
                                                                                                                      
                                                  
  cursor.execute(create_query)
  myconnection.commit()

  vl_list=[]
  db=client["youtube_project"]
  collection=db.chennal_details
  for vl_data in collection.find({"Channel_Name":"Jovash Austin"},{"_id":0}):
      for i in range(len(vl_data["video_information"])):
        vl_list.append(vl_data["video_information"][i])
      
  df5=pd.DataFrame(vl_list)


  
  for index,row in df5.iterrows():
      insert_query='''insert into video_list(Channel_Name,
                                          Channel_Id,
                                          Video_Id,
                                          Title,
                                          Thumbnail,
                                          Comments,
                                          Like_Count,
                                          Dislike_Count,
                                          Faviorite,
                                          Description,
                                          Published_Date,
                                          Duration,
                                          Views,
                                          Definition,
                                          Caption_Status)
                                                                                                                      
                                                  
                                          
                                          values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
                                          
      values=(row["Channel_Name"],
              row["Channel_Id"],
              row["Video_Id"],
              row["Title"],
              row["Thumbnail"],
              row["Comments"],
              row["Like_Count"],
              row["Dislike_Count"],
              row["Faviorite"],
              row["Description"],
              datetime.datetime.strptime(row["Published_Date"],'%Y-%m-%dT%H:%M:%SZ'),
              row["Duration"],
              row["Views"],
              row["Definition"],
              row["Caption_Status"])
      
      cursor.execute(insert_query,values)
      myconnection.commit()

# %%
#FUNCTION OF ALL THE TABLES INFORMATION
def tables():
    channel_information()
    playlist_information()
    comment_information()
    video_information()
    
    return "created"

# %%
table=tables()

# %%
def show_channel_table():

    ch_list=[]
    db=client["youtube_project"]
    collection=db["chennal_details"]
    for ch_data in collection.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
        
    
    df=st.dataframe(ch_list)
    
    return df

# %%
def show_playlist_table():
    pl_list=[]
    db=client["youtube_project"]
    collection=db["chennal_details"]
    for pl_data in collection.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])
        
    df1=st.dataframe(pl_list)

    return df1

# %%
def show_video_table():
    
    vl_list=[]
    db=client["youtube_project"]
    collection=db["chennal_details"]
    for vl_data in collection.find({},{"_id":0,"video_information":1}):
        for i in range(len(vl_data["video_information"])):
           vl_list.append(vl_data["video_information"][i])
        
    df5=st.dataframe(vl_list)

# %%
def show_comment_table():
  cl_list=[]
  db=client["youtube_project"]
  collection=db["chennal_details"]
  for cl_data in collection.find({},{"_id":0,"comment_information":1}):
      for i in range(len(cl_data["comment_information"])):
        cl_list.append(cl_data["comment_information"][i])
      
  df4=st.dataframe(cl_list)
  
  return df4

# %%
#STREAM LIT
with st.sidebar:
    st.title(":purple[YOUTUBE DATA HARVESTING AND WAREHOUSING]")
    st.header("SKILLS AWAY FROM THIS PROJECT")
    st.caption("API integration")
    st.caption("DATA COLLECTION")
    st.caption("PYTHON SCRIPTING")
    st.caption("MONGODB")
    st.caption("DATA MANAGEMENT USING MONGO AND SQL")
    
channel_id=st.text_input("Enter the channel_Id")
if st.button("Collect and Store Data"):
    ch_ids=[]
    db=client["youtube_project"]
    collection=db["channel_details"]
    for ch_data in collection.find({},{"_id":0,"channel_information":1}):
        ch_ids.append(ch_data["channel+information"]["Channel_Id"])
    if channel_id in ch_ids:
        st.success("channel details of the given channel id already exists")
    else:
        insert=chennal_detail(channel_id)
        st.success(insert)
        
if st.button("Migrate of SQL"):
    Table=tables()
    st.success(Table)
show_table=st.radio("select the table for view",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS"))
if show_table=="CHANNELS":
    show_channel_table()
elif show_table=="PLAYLISTS":
    show_playlist_table()
elif show_table=="VIDEOS":
    show_video_table()
elif show_table=="COMMENTS":
    show_comment_table()
# Out:
# 2024-02-12 19:17:45.657
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run d:\youtube project\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
#STREAMLIT QUESTIONS FRAMING
myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='Navi@1996')
cursor=myconnection.cursor()
myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='Navi@1996',database='youtube_project')
cursor=myconnection.cursor()

# %%
question=st.selectbox("Select Your Question",("1.What are the names of all the videos and their corresponding channels?"
                                              "2.Which channels have the most number of videos, and how many videos do they have?"
                                              "3.What are the top 10 most viewed videos and their respective channels?"
                                              "4.How many comments were made on each video, and what are their corresponding video names?"
                                              "5.Which videos have the highest number of likes, and what are their corresponding channel names?"
                                              "6.What is the total number of likes and dislikes for each video, and what are their corresponding video names?"
                                              "7.What is the total number of views for each channel, and what are their corresponding channel names?"
                                              "8.What are the names of all the channels that have published videos in the year2022?"
                                              "9.What is the average duration of all videos in each channel, and what are their corresponding channel names?"
                                              "10.Which videos have the highest number of comments, and what are their corresponding channel names?"))

# %%
myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='Navi@1996')
cursor=myconnection.cursor()
myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='Navi@1996',database='youtube_project')
cursor=myconnection.cursor()


if question=="1.What are the names of all the videos and their corresponding channels?":
    
    query1='''select Title as videos,channel_Name as channelname from video_list'''
    cursor.execute(query1)
    myconnection.commit()
    t1=cursor.fetchall()
    df=pd.DataFrame(t1,columns=["video_title","channel_name"])
    

elif question=="2.Which channels have the most number of videos, and how many videos do they have?":
    query2='''select Channel_Name as channel_name,Total_Videos as no_of_videos from channels order by Total_Videos desc'''
    cursor.execute(query2)
    myconnection.commit()
    t2=cursor.fetchall()
    df1=pd.DataFrame(t2,columns=["channel name","no of videos"])
    
elif question=="3.What are the top 10 most viewed videos and their respective channels?":
    query3='''select Views as views,Channel_Name as channel_name,Title as video_title from video_list  where Views is not null order by TViews desc limit 10'''
    cursor.execute(query3)
    myconnection.commit()
    t3=cursor.fetchall()
    df2=pd.DataFrame(t3,columns=["views,channel_name","video_title"])
    
elif question=="4.How many comments were made on each video, and what are their corresponding video names?":
    query4='''select Comments as no_of_comments,Title as video_title from video_list where Comments is not null'''
    cursor.execute(query4)
    myconnection.commit()
    t4=cursor.fetchall()
    df4=pd.DataFrame(t4,columns=["no_of_comments","video_title"])
    
elif question=="5.Which videos have the highest number of likes, and what are their corresponding channel names?":
    
    
    query5='''select Title as video_title,Channel_Name as channel_name, Like_Count as likes from video_list where Like_Count is not null order by Like_Count desc'''
    cursor.execute(query5)
    myconnection.commit()
    t5=cursor.fetchall()
    df4=pd.DataFrame(t5,columns=["video_title","channel_name","likes"])
    
elif question=="6.What is the total number of likes and dislikes for each video, and what are their corresponding video names?":
    
    query6='''select Like_Count as like_count,Dislike_Count as dislike_count,Title as video_title from video_list'''
    cursor.execute(query6)
    myconnection.commit()
    t6=cursor.fetchall()
    df5=pd.DataFrame(t6,columns=["like_count","dislike_count","video_title"])
    
elif question=="7.What is the total number of views for each channel, and what are their corresponding channel names?":
    query7='''select Views as views,Channel_Name as channel_name from video_list'''
    cursor.execute(query7)
    myconnection.commit()
    t7=cursor.fetchall()
    df6=pd.DataFrame(t7,columns=["views","channel_name"])

elif question=="8.What are the names of all the channels that have published videos in the year2022?":
    query8='''select Title as video_title,Published_Date as published_date,Channel_Name as channel_name from video_list 
            where extract(year from Published_Date)=2022'''
    cursor.execute(query8)
    myconnection.commit()
    t8=cursor.fetchall()
    df7=pd.DataFrame(t8,columns=["video_title","published_date","channel_name"])
    
elif question=="9.What is the average duration of all videos in each channel, and what are their corresponding channel names?":
    query9='''Channel_Name as channel_name,AVG(Duration) as avarageduration from video_list  group by Channel_Name'''

    cursor.execute(query9)
    myconnection.commit()
    t9=cursor.fetchall()
    df8=pd.DataFrame(t9,columns=["video_title","published_date","channel_name"])
    
elif question==("10.Which videos have the highest number of comments, and what are their corresponding channel names?"):

    query10='''select Title as video_title,Comments as comments,Channel_Name as channel_name from video_list where Comments is not null order by Comments desc'''
    cursor.execute(query10)
    myconnection.commit()
    t10=cursor.fetchall()
    df9=pd.DataFrame(t10,columns=["video_title","comments","channel_name"])
